# %% [markdown]
# # Artificial Intelligence Nanodegree
#
# ## Convolutional Neural Networks
#
# ## Project: Write an Algorithm for a Dog Identification App
#
# ---
#
# In this notebook, some template code has already been provided for you, and you will need to implement additional functionality to successfully complete this project. You will not need to modify the included code beyond what is requested. Sections that begin with **'(IMPLEMENTATION)'** in the header indicate that the following block of code will require additional functionality which you must provide. Instructions will be provided for each section, and the specifics of the implementation are marked in the code block with a 'TODO' statement. Please be sure to read the instructions carefully!
#
# > **Note**: Once you have completed all of the code implementations, you need to finalize your work by exporting the iPython Notebook as an HTML document. Before exporting the notebook to html, all of the code cells need to have been run so that reviewers can see the final implementation and output. You can then export the notebook by using the menu above and navigating to  \n",
#     "**File -> Download as -> HTML (.html)**. Include the finished document along with this notebook as your submission.
#
# In addition to implementing code, there will be questions that you must answer which relate to the project and your implementation. Each section where you will answer a question is preceded by a **'Question X'** header. Carefully read each question and provide thorough answers in the following text boxes that begin with **'Answer:'**. Your project submission will be evaluated based on your answers to each of the questions and the implementation you provide.
#
# >**Note:** Code and Markdown cells can be executed using the **Shift + Enter** keyboard shortcut.  Markdown cells can be edited by double-clicking the cell to enter edit mode.
#
# The rubric contains _optional_ "Stand Out Suggestions" for enhancing the project beyond the minimum requirements. If you decide to pursue the "Stand Out Suggestions", you should include the code in this IPython notebook.
#
#
#
# ---
# ### Why We're Here
#
# In this notebook, you will make the first steps towards developing an algorithm that could be used as part of a mobile or web app.  At the end of this project, your code will accept any user-supplied image as input.  If a dog is detected in the image, it will provide an estimate of the dog's breed.  If a human is detected, it will provide an estimate of the dog breed that is most resembling.  The image below displays potential sample output of your finished project (... but we expect that each student's algorithm will behave differently!).
#
# ![Sample Dog Output](images/sample_dog_output.png)
#
# In this real-world setting, you will need to piece together a series of models to perform different tasks; for instance, the algorithm that detects humans in an image will be different from the CNN that infers dog breed.  There are many points of possible failure, and no perfect algorithm exists.  Your imperfect solution will nonetheless create a fun user experience!
#
# ### The Road Ahead
#
# We break the notebook into separate steps.  Feel free to use the links below to navigate the notebook.
#
# * [Step 0](#step0): Import Datasets
# * [Step 1](#step1): Detect Humans
# * [Step 2](#step2): Detect Dogs
# * [Step 3](#step3): Create a CNN to Classify Dog Breeds (from Scratch)
# * [Step 4](#step4): Use a CNN to Classify Dog Breeds (using Transfer Learning)
# * [Step 5](#step5): Create a CNN to Classify Dog Breeds (using Transfer Learning)
# * [Step 6](#step6): Write your Algorithm
# * [Step 7](#step7): Test Your Algorithm
#
# ---
# <a id='step0'></a>
# ## Step 0: Import Datasets
#
# ### Import Dog Dataset
#
# In the code cell below, we import a dataset of dog images.  We populate a few variables through the use of the `load_files` function from the scikit-learn library:
# - `train_files`, `valid_files`, `test_files` - numpy arrays containing file paths to images
# - `train_targets`, `valid_targets`, `test_targets` - numpy arrays containing onehot-encoded classification labels
# - `dog_names` - list of string-valued dog breed names for translating labels

# %%
from sklearn.datasets import load_files       
from keras.utils import np_utils
import numpy as np
from glob import glob

# define function to load train, test, and validation datasets
def load_dataset(path):
    data = load_files(path)
    dog_files = np.array(data['filenames'])
    dog_targets = np_utils.to_categorical(np.array(data['target']), 133)
    return dog_files, dog_targets

# load train, test, and validation datasets
train_files, train_targets = load_dataset('dogImages/train')
valid_files, valid_targets = load_dataset('dogImages/valid')
test_files, test_targets = load_dataset('dogImages/test')

# load list of dog names
dog_names = [item[20:-1] for item in sorted(glob("dogImages/train/*/"))]

# print statistics about the dataset
print('There are %d total dog categories.' % len(dog_names))
print('There are %s total dog images.\n' % len(np.hstack([train_files, valid_files, test_files])))
print('There are %d training dog images.' % len(train_files))
print('There are %d validation dog images.' % len(valid_files))
print('There are %d test dog images.'% len(test_files))
# Out:
# Using TensorFlow backend.
# There are 133 total dog categories.
# There are 8351 total dog images.
#
# There are 6680 training dog images.
# There are 835 validation dog images.
# There are 836 test dog images.

# %% [markdown]
# ### Import Human Dataset
#
# In the code cell below, we import a dataset of human images, where the file paths are stored in the numpy array `human_files`.

# %%
import random
random.seed(8675309)

# load filenames in shuffled human dataset
human_files = np.array(glob("lfw/*/*"))
random.shuffle(human_files)

# print statistics about the dataset
print('There are %d total human images.' % len(human_files))
# Out:
# There are 13233 total human images.

# %% [markdown]
# ---
# <a id='step1'></a>
# ## Step 1: Detect Humans
#
# We use OpenCV's implementation of [Haar feature-based cascade classifiers](http://docs.opencv.org/trunk/d7/d8b/tutorial_py_face_detection.html) to detect human faces in images.  OpenCV provides many pre-trained face detectors, stored as XML files on [github](https://github.com/opencv/opencv/tree/master/data/haarcascades).  We have downloaded one of these detectors and stored it in the `haarcascades` directory.
#
# In the next code cell, we demonstrate how to use this detector to find human faces in a sample image.

# %%
import cv2 as cv2                
import matplotlib.pyplot as plt                        
# %matplotlib inline                               

# extract pre-trained face detector
face_cascade = cv2.CascadeClassifier('haarcascades/haarcascade_frontalface_alt.xml')

# load color (BGR) image
img = cv2.imread(human_files[3])
# convert BGR image to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# find faces in image
faces = face_cascade.detectMultiScale(gray)

# print number of faces detected in the image
print('Number of faces detected:', len(faces))

# get bounding box for each detected face
for (x,y,w,h) in faces:
    # add bounding box to color image
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    
# convert BGR image to RGB for plotting
cv_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# display the image, along with bounding box
plt.imshow(cv_rgb)
plt.show()
# Out:
# ('Number of faces detected:', 1)

# %% [markdown]
# Before using any of the face detectors, it is standard procedure to convert the images to grayscale.  The `detectMultiScale` function executes the classifier stored in `face_cascade` and takes the grayscale image as a parameter.
#
# In the above code, `faces` is a numpy array of detected faces, where each row corresponds to a detected face.  Each detected face is a 1D array with four entries that specifies the bounding box of the detected face.  The first two entries in the array (extracted in the above code as `x` and `y`) specify the horizontal and vertical positions of the top left corner of the bounding box.  The last two entries in the array (extracted here as `w` and `h`) specify the width and height of the box.
#
# ### Write a Human Face Detector
#
# We can use this procedure to write a function that returns `True` if a human face is detected in an image and `False` otherwise.  This function, aptly named `face_detector`, takes a string-valued file path to an image as input and appears in the code block below.

# %%
# returns "True" if face is detected in image stored at img_path
def face_detector(img_path):
    img = cv2.imread(img_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray)
    return len(faces) > 0

# %% [markdown]
# ### (IMPLEMENTATION) Assess the Human Face Detector
#
# __Question 1:__ Use the code cell below to test the performance of the `face_detector` function.
# - What percentage of the first 100 images in `human_files` have a detected human face?
# - What percentage of the first 100 images in `dog_files` have a detected human face?
#
# Ideally, we would like 100% of human images with a detected face and 0% of dog images with a detected face.  You will see that our algorithm falls short of this goal, but still gives acceptable performance.  We extract the file paths for the first 100 images from each of the datasets and store them in the numpy arrays `human_files_short` and `dog_files_short`.
#
# __Answer:__

# %%
human_files_short = human_files[:100]
dog_files_short = train_files[:100]
# Do NOT modify the code above this line.

## TODO: Test the performance of the face_detector algorithm 
## on the images in human_files_short and dog_files_short.
human_detected = [human for human in human_files_short if face_detector(human)]
human_percentage = len(human_detected) * 1.
print("Human percentage: {}%".format(human_percentage))
dog_detected = [dog for dog in dog_files_short if face_detector(dog)]
dog_percentage = len(dog_detected) * 1.
print("Dog percentage: {}%".format(dog_percentage))
# Out:
# Human percentage: 100.0%
# Dog percentage: 12.0%

# %% [markdown]
# __Question 2:__ This algorithmic choice necessitates that we communicate to the user that we accept human images only when they provide a clear view of a face (otherwise, we risk having unneccessarily frustrated users!). In your opinion, is this a reasonable expectation to pose on the user? If not, can you think of a way to detect humans in images that does not necessitate an image with a clearly presented face?
#
# __Answer:__
#
# We suggest the face detector from OpenCV as a potential way to detect human images in your algorithm, but you are free to explore other approaches, especially approaches that make use of deep learning :).  Please use the code cell below to design and test your own face detection algorithm.  If you decide to pursue this _optional_ task, report performance on each of the datasets.

# %%
## (Optional) TODO: Report the performance of another  
## face detection algorithm on the LFW dataset
### Feel free to use as many code cells as needed.
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Activation
from keras.layers import Dropout, Flatten, Dense
from keras.models import Sequential
from keras.callbacks import ModelCheckpoint

def load_resized(img_path):
    print("Img: {}".format(img_path))
    img = cv2.imread(img_path)
    return cv2.resize(img, (224, 224))

humans_X = [load_resized(i) for i in human_files]
dogs_X = [load_resized(i) for i in train_files]
# Out:
# Img: lfw/Tony_Blair/Tony_Blair_0019.jpg
# Img: lfw/Mauricio_Macri/Mauricio_Macri_0001.jpg
# Img: lfw/Andrew_Weissmann/Andrew_Weissmann_0001.jpg
# Img: lfw/Lou_Piniella/Lou_Piniella_0001.jpg
# Img: lfw/Cherry_Jones/Cherry_Jones_0001.jpg
# Img: lfw/Melana_Scantlin/Melana_Scantlin_0001.jpg
# Img: lfw/Juan_Carlos_Ferrero/Juan_Carlos_Ferrero_0009.jpg
# Img: lfw/Zdravko_Mucic/Zdravko_Mucic_0001.jpg
# Img: lfw/GL_Peiris/GL_Peiris_0004.jpg
# Img: lfw/Hillary_Clinton/Hillary_Clinton_0005.jpg
# Img: lfw/Nathan_Lane/Nathan_Lane_0002.jpg
# Img: lfw/Jean_Chretien/Jean_Chretien_0022.jpg
# Img: lfw/Bill_Gates/Bill_Gates_0017.jpg
# Img: lfw/Spencer_Abraham/Spencer_Abraham_0004.jpg
# Img: lfw/Jim_Leach/Jim_Leach_0001.jpg
# Img: lfw/Michael_Broad/Michael_Broad_0001.jpg
# Img: lfw/Colin_Powell/Colin_Powell_0048.jpg
# Img: lfw/Recep_Tayyip_Erdogan/Recep_Tayyip_Erdogan_0028.jpg
# Img: lfw/Bob_Petrino/Bob_Petrino_0001.jpg
# Img: lfw/Jackie_Chan/Jackie_Chan_0009.jpg
# Img: lfw/Yoko_Ono/Yoko_Ono_0002.jpg
# Img: lfw/George_W_Bush/George_W_Bush_0422.jpg
# Img: lfw/Mike_Weir/Mike_Weir_0002.jpg
# Img: lfw/Yves_Brodeur/Yves_Brodeur_0001.jpg
# Img: lfw/Pete_Carroll/Pete_Carroll_0001.jpg
# Img: lfw/Leland_Chapman/Leland_Chapman_0001.jpg
# Img: lfw/Thierry_Falise/Thierry_Falise_0002.jpg
# Img: lfw/Mark_Martin/Mark_Martin_0001.jpg
# Img: lfw/Alecos_Markides/Alecos_Markides_0001.jpg
# Img: lfw/Ronald_Ito/Ronald_Ito_0001.jpg
# Img: lfw/Ruano_Pascual/Ruano_Pascual_0001.jpg
# Img: lfw/David_Nalbandian/David_Nalbandian_0014.jpg
# Img: lfw/Arnold_Schwarzenegger/Arnold_Schwarzenegger_0016.jpg
# Img: lfw/Emily_Mason/Emily_Mason_0001.jpg
# Img: lfw/Jennifer_Capriati/Jennifer_Capriati_0010.jpg
# Img: lfw/Rose_Linkins/Rose_Linkins_0001.jpg
# Img: lfw/Carlo_Ancelotti/Carlo_Ancelotti_0002.jpg
# Img: lfw/Sebastien_Grosjean/Sebastien_Grosjean_0004.jpg
# Img: lfw/Carlos_Quintanilla_Schmidt/Carlos_Quintanilla_Schmidt_0002.jpg
# Img: lfw/Hugo_Chavez/Hugo_Chavez_0013.jpg
# Img: lfw/Kobe_Bryant/Kobe_Bryant_0002.jpg
# Img: lfw/Brenda_van_Dam/Brenda_van_Dam_0001.jpg
# Img: lfw/Luis_Figo/Luis_Figo_0004.jpg
# Img: lfw/Alma_Powell/Alma_Powell_0001.jpg
# Img: lfw/Dimitri_Perricos/Dimitri_Perricos_0001.jpg
# Img: lfw/Laurent_Jalabert/Laurent_Jalabert_0002.jpg
# Img: lfw/Ari_Fleischer/Ari_Fleischer_0012.jpg
# Img: lfw/Laura_Bush/Laura_Bush_0012.jpg
# Img: lfw/Lleyton_Hewitt/Lleyton_Hewitt_0029.jpg
# Img: lfw/Javier_Delgado/Javier_Delgado_0001.jpg
# Img: lfw/Silvio_Berlusconi/Silvio_Berlusconi_0016.jpg
# Img: lfw/Paradorn_Srichaphan/Paradorn_Srichaphan_0010.jpg
# Img: lfw/Jean-Marc_de_La_Sabliere/Jean-Marc_de_La_Sabliere_0001.jpg
# Img: lfw/Ralph_Lauren/Ralph_Lauren_0001.jpg
# Img: lfw/Augustin_Calleri/Augustin_Calleri_0002.jpg
# Img: lfw/Mickey_Sherman/Mickey_Sherman_0001.jpg
# Img: lfw/Queen_Sofia/Queen_Sofia_0001.jpg
# Img: lfw/Shimon_Peres/Shimon_Peres_0007.jpg
# Img: lfw/Ed_Book/Ed_Book_0001.jpg
# Img: lfw/Trent_Lott/Trent_Lott_0009.jpg
# Img: lfw/Alyse_Beaupre/Alyse_Beaupre_0001.jpg
# Img: lfw/Jean-Claude_Trichet/Jean-Claude_Trichet_0002.jpg
# Img: lfw/Tom_Crean/Tom_Crean_0004.jpg
# Img: lfw/Ray_Wasden/Ray_Wasden_0001.jpg
# Img: lfw/Petria_Thomas/Petria_Thomas_0001.jpg
# Img: lfw/Andre_Agassi/Andre_Agassi_0009.jpg
# Img: lfw/William_Bulger/William_Bulger_0001.jpg
# Img: lfw/George_W_Bush/George_W_Bush_0078.jpg
# Img: lfw/Pedro_Almodovar/Pedro_Almodovar_0003.jpg
# Img: lfw/Adel_Al-Jubeir/Adel_Al-Jubeir_0001.jpg
# Img: lfw/Joseph_Estrada/Joseph_Estrada_0001.jpg
# Img: lfw/Jennifer_Capriati/Jennifer_Capriati_0015.jpg
# Img: lfw/Tom_Glavine/Tom_Glavine_0001.jpg
# Img: lfw/William_Overlin/William_Overlin_0001.jpg
# Img: lfw/Brian_Jordan/Brian_Jordan_0001.jpg
# Img: lfw/Brennon_Leighton/Brennon_Leighton_0001.jpg
# Img: lfw/Elsa_Zylberstein/Elsa_Zylberstein_0002.jpg
# Img: lfw/Jamling_Norgay/Jamling_Norgay_0001.jpg
# Img: lfw/Nestor_Kirchner/Nestor_Kirchner_0017.jpg
# Img: lfw/Robbie_Mc_Ewen/Robbie_Mc_Ewen_0001.jpg
# Img: lfw/Dai_Bachtiar/Dai_Bachtiar_0002.jpg
# Img: lfw/Harvey_Wachsman/Harvey_Wachsman_0001.jpg
# Img: lfw/Tex_Ritter/Tex_Ritter_0001.jpg
# Img: lfw/Hans_Blix/Hans_Blix_0033.jpg
# Img: lfw/Larry_Brown/Larry_Brown_0007.jpg
# Img: lfw/Paul_Burrell/Paul_Burrell_0009.jpg
# Img: lfw/John_Ashcroft/John_Ashcroft_0032.jpg
# Img: lfw/Nicolas_Cage/Nicolas_Cage_0001.jpg
# Img: lfw/Yasser_Arafat/Yasser_Arafat_0002.jpg
# Img: lfw/Natasha_Henstridge/Natasha_Henstridge_0001.jpg
# Img: lfw/Kate_Capshaw/Kate_Capshaw_0001.jpg
# Img: lfw/Gao_Qiang/Gao_Qiang_0002.jpg
# Img: lfw/Gary_Bald/Gary_Bald_0001.jpg
# Img: lfw/Bernard_Law/Bernard_Law_0004.jpg
# Img: lfw/Bruce_Springsteen/Bruce_Springsteen_0004.jpg
# Img: lfw/Dominick_Dunne/Dominick_Dunne_0001.jpg
# Img: lfw/Bulent_Ecevit/Bulent_Ecevit_0001.jpg
# Img: lfw/Li_Ka-shing/Li_Ka-shing_0001.jpg
# Img: lfw/Samira_Makhmalbaf/Samira_Makhmalbaf_0001.jpg
# Img: lfw/Charlotte_Rampling/Charlotte_Rampling_0002.jpg
# Img: lfw/Charlton_Heston/Charlton_Heston_0004.jpg
# Img: lfw/Keira_Knightley/Keira_Knightley_0002.jpg
# Img: lfw/Keith_Osik/Keith_Osik_0001.jpg
# Img: lfw/Gina_Lollobrigida/Gina_Lollobrigida_0001.jpg
# Img: lfw/Dora_Bakoyianni/Dora_Bakoyianni_0001.jpg
# Img: lfw/Hama_Arba_Diallo/Hama_Arba_Diallo_0001.jpg
# Img: lfw/Jennifer_Aniston/Jennifer_Aniston_0001.jpg
# Img: lfw/Ana_Palacio/Ana_Palacio_0006.jpg
# Img: lfw/Pablo_Khulental/Pablo_Khulental_0001.jpg
# Img: lfw/Jeremy_Greenstock/Jeremy_Greenstock_0010.jpg
# Img: lfw/John_Henry/John_Henry_0001.jpg
# Img: lfw/James_Wattana/James_Wattana_0001.jpg
# Img: lfw/George_Clooney/George_Clooney_0008.jpg
# Img: lfw/Paradorn_Srichaphan/Paradorn_Srichaphan_0008.jpg
# Img: lfw/Sally_Kirkland/Sally_Kirkland_0004.jpg
# Img: lfw/Jennifer_Capriati/Jennifer_Capriati_0033.jpg
# Img: lfw/Jim_Wall/Jim_Wall_0001.jpg
# Img: lfw/Kim_Dae-jung/Kim_Dae-jung_0003.jpg
# Img: lfw/Peter_Struck/Peter_Struck_0001.jpg
# Img: lfw/George_Ryan/George_Ryan_0003.jpg
# Img: lfw/Donald_Rumsfeld/Donald_Rumsfeld_0025.jpg
# Img: lfw/Robert_Nillson/Robert_Nillson_0001.jpg
# Img: lfw/Shingo_Suetsugu/Shingo_Suetsugu_0001.jpg
# Img: lfw/Ariel_Sharon/Ariel_Sharon_0061.jpg
# Img: lfw/Fazal-ur-Rehman/Fazal-ur-Rehman_0001.jpg
# Img: lfw/Tom_Gamboa/Tom_Gamboa_0001.jpg
# Img: lfw/Alanna_Ubach/Alanna_Ubach_0001.jpg
# Img: lfw/Marie-Reine_Le_Gougne/Marie-Reine_Le_Gougne_0001.jpg
# Img: lfw/Debbie_Reynolds/Debbie_Reynolds_0002.jpg
# Img: lfw/Norm_Coleman/Norm_Coleman_0003.jpg
# Img: lfw/Silvio_Berlusconi/Silvio_Berlusconi_0015.jpg
# Img: lfw/Nicole_Kidman/Nicole_Kidman_0009.jpg
# Img: lfw/Martha_Burk/Martha_Burk_0001.jpg
# Img: lfw/Donald_Rumsfeld/Donald_Rumsfeld_0038.jpg
# Img: lfw/Tom_Hanusik/Tom_Hanusik_0001.jpg
# Img: lfw/Tom_Coughlin/Tom_Coughlin_0001.jpg
# Img: lfw/Dawna_LoPiccolo/Dawna_LoPiccolo_0001.jpg
# Img: lfw/Mike_Tyson/Mike_Tyson_0002.jpg
# Img: lfw/George_W_Bush/George_W_Bush_0494.jpg
# Img: lfw/Paula_Zahn/Paula_Zahn_0001.jpg
# Img: lfw/Elvis_Stojko/Elvis_Stojko_0001.jpg
# Img: lfw/Jean-Pierre_Raffarin/Jean-Pierre_Raffarin_0003.jpg
# Img: lfw/Mahmoud_Abbas/Mahmoud_Abbas_0001.jpg
# Img: lfw/Ricardo_Sanchez/Ricardo_Sanchez_0005.jpg
# Img: lfw/Ian_Thorpe/Ian_Thorpe_0002.jpg
# Img: lfw/Bode_Miller/Bode_Miller_0002.jpg
# Img: lfw/Silvio_Berlusconi/Silvio_Berlusconi_0030.jpg
# Img: lfw/Terry_Hoeppner/Terry_Hoeppner_0001.jpg
# Img: lfw/Mike_Samp/Mike_Samp_0001.jpg
# Img: lfw/Gloria_Macapagal_Arroyo/Gloria_Macapagal_Arroyo_0021.jpg
# Img: lfw/Keanu_Reeves/Keanu_Reeves_0010.jpg
# Img: lfw/Chris_Gratton/Chris_Gratton_0001.jpg
# Img: lfw/Martin_Rodriguez/Martin_Rodriguez_0001.jpg
# Img: lfw/Junichi_Inamoto/Junichi_Inamoto_0001.jpg
# Img: lfw/George_W_Bush/George_W_Bush_0027.jpg
# Img: lfw/Rebekah_Chantay_Revels/Rebekah_Chantay_Revels_0002.jpg
# Img: lfw/Clay_Campbell/Clay_Campbell_0001.jpg
# Img: lfw/Carlos_Ruckauf/Carlos_Ruckauf_0001.jpg
# Img: lfw/Alfredo_di_Stefano/Alfredo_di_Stefano_0001.jpg
# Img: lfw/Bill_Clinton/Bill_Clinton_0004.jpg
# Img: lfw/Mary_Carey/Mary_Carey_0001.jpg
# Img: lfw/Sandy_Wise/Sandy_Wise_0001.jpg
# Img: lfw/George_W_Bush/George_W_Bush_0029.jpg
# Img: lfw/George_P_Bush/George_P_Bush_0001.jpg
# Img: lfw/Dan_Snyder/Dan_Snyder_0001.jpg
# Img: lfw/Guillermo_Coria/Guillermo_Coria_0029.jpg
# Img: lfw/Jennifer_Keller/Jennifer_Keller_0002.jpg
# Img: lfw/Jean_Chretien/Jean_Chretien_0055.jpg
# Img: lfw/Silvio_Berlusconi/Silvio_Berlusconi_0002.jpg
# Img: lfw/Justin_Leonard/Justin_Leonard_0003.jpg
# Img: lfw/Colin_Powell/Colin_Powell_0220.jpg
# Img: lfw/Luis_Gonzalez_Macchi/Luis_Gonzalez_Macchi_0004.jpg
# Img: lfw/Mian_Khursheed_Mehmood_Kasuri/Mian_Khursheed_Mehmood_Kasuri_0002.jpg
# Img: lfw/Charles_Moose/Charles_Moose_0004.jpg
# Img: lfw/Art_Hoffmann/Art_Hoffmann_0002.jpg
# Img: lfw/Michael_Shane_Jolly/Michael_Shane_Jolly_0001.jpg
# Img: lfw/Tiger_Woods/Tiger_Woods_0011.jpg
# Img: lfw/Dennis_Kucinich/Dennis_Kucinich_0007.jpg
# Img: lfw/Keanu_Reeves/Keanu_Reeves_0007.jpg
# Img: lfw/George_W_Bush/George_W_Bush_0099.jpg
# Img: lfw/Norm_Coleman/Norm_Coleman_0002.jpg
# Img: lfw/Colin_Powell/Colin_Powell_0177.jpg
# Img: lfw/John_Nash/John_Nash_0001.jpg
# Img: lfw/Jesse_James/Jesse_James_0001.jpg
# Img: lfw/Dennis_Hastert/Dennis_Hastert_0001.jpg
# Img: lfw/Andre_Agassi/Andre_Agassi_0027.jpg
# Img: lfw/Angela_Lansbury/Angela_Lansbury_0002.jpg
# Img: lfw/Wanda_de_la_Jesus/Wanda_de_la_Jesus_0001.jpg
# Img: lfw/Kim_Clijsters/Kim_Clijsters_0013.jpg
# Img: lfw/Jim_Tressel/Jim_Tressel_0001.jpg
# Img: lfw/Naji_Sabri/Naji_Sabri_0004.jpg
# Img: lfw/Tony_Blair/Tony_Blair_0030.jpg
# Img: lfw/Arnold_Schwarzenegger/Arnold_Schwarzenegger_0032.jpg
# Img: lfw/Paradorn_Srichaphan/Paradorn_Srichaphan_0002.jpg
# Img: lfw/Jennifer_Capriati/Jennifer_Capriati_0021.jpg
# Img: lfw/Hugo_Chavez/Hugo_Chavez_0033.jpg
# Img: lfw/Christine_Todd_Whitman/Christine_Todd_Whitman_0006.jpg
# Img: lfw/Yukiko_Okudo/Yukiko_Okudo_0001.jpg
# Img: lfw/Hamid_Karzai/Hamid_Karzai_0011.jpg
# Img: lfw/Stephanie_Zimbalist/Stephanie_Zimbalist_0001.jpg
# Img: lfw/John_Ashcroft/John_Ashcroft_0015.jpg
# Img: lfw/Andy_Madikians/Andy_Madikians_0001.jpg
# Img: lfw/Abel_Pacheco/Abel_Pacheco_0001.jpg
# Img: lfw/George_W_Bush/George_W_Bush_0044.jpg
# Img: lfw/Martin_Verkerk/Martin_Verkerk_0002.jpg
# Img: lfw/George_W_Bush/George_W_Bush_0415.jpg
# Img: lfw/Carroll_Weimer/Carroll_Weimer_0001.jpg
# Img: lfw/Jonathan_Woodgate/Jonathan_Woodgate_0001.jpg
# Img: lfw/Wes_Craven/Wes_Craven_0001.jpg
# Img: lfw/Branko_Crvenkovski/Branko_Crvenkovski_0002.jpg
# Img: lfw/Michael_Munoz/Michael_Munoz_0001.jpg
# Img: lfw/Bill_Gates/Bill_Gates_0016.jpg
# Img: lfw/Vincent_Brooks/Vincent_Brooks_0006.jpg
# Img: lfw/Gerhard_Schroeder/Gerhard_Schroeder_0009.jpg
# Img: lfw/Gabriel_Hughes/Gabriel_Hughes_0001.jpg
# Img: lfw/Heidi_Klum/Heidi_Klum_0003.jpg
# Img: lfw/Will_Ofenheusle/Will_Ofenheusle_0001.jpg
# Img: lfw/Chris_Noth/Chris_Noth_0001.jpg
# Img: lfw/Hugh_Miller/Hugh_Miller_0001.jpg
# Img: lfw/Amanda_Bynes/Amanda_Bynes_0004.jpg
# Img: lfw/Deb_Santos/Deb_Santos_0001.jpg
# Img: lfw/Ricardo_Lagos/Ricardo_Lagos_0005.jpg
# Img: lfw/George_W_Bush/George_W_Bush_0058.jpg
# Img: lfw/Tubby_Smith/Tubby_Smith_0002.jpg
# Img: lfw/Enos_Slaughter/Enos_Slaughter_0001.jpg
# Img: lfw/Kelvin_Sampson/Kelvin_Sampson_0002.jpg
# Img: lfw/Abid_Hamid_Mahmud_Al-Tikriti/Abid_Hamid_Mahmud_Al-Tikriti_0001.jpg
# Img: lfw/David_Arquette/David_Arquette_0001.jpg
# Img: lfw/Yuri_Malenchenko/Yuri_Malenchenko_0002.jpg
# Img: lfw/Jacques_Chirac/Jacques_Chirac_0041.jpg
# Img: lfw/Colin_Powell/Colin_Powell_0022.jpg
# Img: lfw/Luis_Horna/Luis_Horna_0006.jpg
# Img: lfw/Vin_Diesel/Vin_Diesel_0002.jpg
# Img: lfw/Mariangel_Ruiz_Torrealba/Mariangel_Ruiz_Torrealba_0003.jpg
# Img: lfw/Christine_Todd_Whitman/Christine_Todd_Whitman_0005.jpg
# Img: lfw/Marco_Pantani/Marco_Pantani_0001.jpg
# Img: lfw/Tommy_Lewis/Tommy_Lewis_0001.jpg
# Img: lfw/Gerhard_Schroeder/Gerhard_Schroeder_0071.jpg
# Img: lfw/Scott_Peterson/Scott_Peterson_0002.jpg
# Img: lfw/John_Lynch/John_Lynch_0001.jpg
# Img: lfw/Luiz_Inacio_Lula_da_Silva/Luiz_Inacio_Lula_da_Silva_0038.jpg
# Img: lfw/Soon_Yi/Soon_Yi_0001.jpg
# Img: lfw/Ralph_Goodale/Ralph_Goodale_0001.jpg
# Img: lfw/Holly_Hunter/Holly_Hunter_0002.jpg
# Img: lfw/Junichiro_Koizumi/Junichiro_Koizumi_0027.jpg
# Img: lfw/Doug_Collins/Doug_Collins_0002.jpg
# Img: lfw/Michael_Bloomberg/Michael_Bloomberg_0015.jpg
# Img: lfw/Lisa_Raymond/Lisa_Raymond_0002.jpg
# Img: lfw/Dominique_de_Villepin/Dominique_de_Villepin_0001.jpg
# Img: lfw/Mike_Alden/Mike_Alden_0001.jpg
# Img: lfw/Malik_Mahmud/Malik_Mahmud_0001.jpg
# Img: lfw/Derrick_Battie/Derrick_Battie_0001.jpg
# Img: lfw/Elizabeth_Hurley/Elizabeth_Hurley_0005.jpg
# Img: lfw/Hisham_Halawi/Hisham_Halawi_0001.jpg
# Img: lfw/Vince_Carter/Vince_Carter_0004.jpg
# Img: lfw/Peter_Rasmussen/Peter_Rasmussen_0001.jpg
# Img: lfw/Mike_Martz/Mike_Martz_0004.jpg
# Img: lfw/Bijan_Darvish/Bijan_Darvish_0003.jpg
# Img: lfw/Flavia_Delaroli/Flavia_Delaroli_0002.jpg
# Img: lfw/Hugo_Chavez/Hugo_Chavez_0011.jpg
# Img: lfw/Peter_Mackay/Peter_Mackay_0001.jpg
# Img: lfw/Natalie_Coughlin/Natalie_Coughlin_0005.jpg
# Img: lfw/Vaclav_Havel/Vaclav_Havel_0003.jpg
# Img: lfw/Colin_Powell/Colin_Powell_0235.jpg
# Img: lfw/Edward_James_Olmos/Edward_James_Olmos_0002.jpg
# Img: lfw/Sophia_Loren/Sophia_Loren_0007.jpg
# Img: lfw/James_Phelps/James_Phelps_0001.jpg
# Img: lfw/Keith_Van_Horn/Keith_Van_Horn_0001.jpg
# Img: lfw/Ralf_Schumacher/Ralf_Schumacher_0003.jpg
# Img: lfw/Prince_Philippe/Prince_Philippe_0001.jpg
# Img: lfw/Vicente_Fox/Vicente_Fox_0023.jpg
# Img: lfw/Paul_McCartney/Paul_McCartney_0004.jpg
# Img: lfw/Keith_Lockhart/Keith_Lockhart_0001.jpg
# Img: lfw/Colin_Powell/Colin_Powell_0136.jpg
# Img: lfw/Mitchell_Daniels/Mitchell_Daniels_0004.jpg
# Img: lfw/Priscilla_Presley/Priscilla_Presley_0002.jpg
# Img: lfw/Barry_Williams/Barry_Williams_0001.jpg
# Img: lfw/Ken_Watanabe/Ken_Watanabe_0001.jpg
# Img: lfw/Habib_Rizieq/Habib_Rizieq_0002.jpg
# Img: lfw/Willie_Nelson/Willie_Nelson_0001.jpg
# Img: lfw/Katie_Harman/Katie_Harman_0002.jpg
# Img: lfw/Nestor_Kirchner/Nestor_Kirchner_0020.jpg
# Img: lfw/Marcelo_Salas/Marcelo_Salas_0002.jpg
# Img: lfw/Tracy_McGrady/Tracy_McGrady_0002.jpg
# Img: lfw/Hector_Mitelman/Hector_Mitelman_0001.jpg
# Img: lfw/John_Edwards/John_Edwards_0004.jpg
# Img: lfw/Bela_Karolyi/Bela_Karolyi_0001.jpg
# Img: lfw/Vincent_Brooks/Vincent_Brooks_0004.jpg
# Img: lfw/Dionigi_Tettamanzi/Dionigi_Tettamanzi_0001.jpg
# Img: lfw/Junko_Tabei/Junko_Tabei_0001.jpg
# Img: lfw/George_W_Bush/George_W_Bush_0156.jpg
# Img: lfw/Colin_Powell/Colin_Powell_0045.jpg
# Img: lfw/Jennifer_Aniston/Jennifer_Aniston_0007.jpg
# Img: lfw/Chung_Mong-joon/Chung_Mong-joon_0001.jpg
# Img: lfw/Jennifer_Capriati/Jennifer_Capriati_0037.jpg
# Img: lfw/Bernard_Law/Bernard_Law_0001.jpg
# Img: lfw/Al_Gore/Al_Gore_0004.jpg
# Img: lfw/Thomas_Bjorn/Thomas_Bjorn_0002.jpg
# Img: lfw/Kim_Dae-jung/Kim_Dae-jung_0001.jpg
# Img: lfw/Jorge_Castaneda/Jorge_Castaneda_0001.jpg
# Img: lfw/Marco_Irizarry/Marco_Irizarry_0001.jpg
# Img: lfw/Holly_Hunter/Holly_Hunter_0004.jpg
# Img: lfw/Hans_Blix/Hans_Blix_0028.jpg
# Img: lfw/Gonzalo_Sanchez_de_Lozada/Gonzalo_Sanchez_de_Lozada_0007.jpg
# Img: lfw/Kofi_Annan/Kofi_Annan_0029.jpg
# Img: lfw/Luis_Ernesto_Derbez_Bautista/Luis_Ernesto_Derbez_Bautista_0001.jpg
# Img: lfw/Carl_Reiner/Carl_Reiner_0001.jpg
# Img: lfw/William_Ford_Jr/William_Ford_Jr_0005.jpg
# Img: lfw/Nancy_Reagan/Nancy_Reagan_0002.jpg
# Img: lfw/Oleksandr_Moroz/Oleksandr_Moroz_0001.jpg
# Img: lfw/Kirby_Puckett/Kirby_Puckett_0001.jpg
# Img: lfw/Gloria_Macapagal_Arroyo/Gloria_Macapagal_Arroyo_0006.jpg
# Img: lfw/Norman_Jewison/Norman_Jewison_0001.jpg
# Img: lfw/Jean-David_Levitte/Jean-David_Levitte_0002.jpg
# Img: lfw/John_Dallager/John_Dallager_0001.jpg
# Img: lfw/Mike_Weir/Mike_Weir_0010.jpg
# Img: lfw/Bill_Clinton/Bill_Clinton_0028.jpg
# Img: lfw/Michael_Sullivan/Michael_Sullivan_0001.jpg
# Img: lfw/Colin_Powell/Colin_Powell_0009.jpg
# Img: lfw/Jonathan_Edwards/Jonathan_Edwards_0003.jpg
# Img: lfw/Du_Qinglin/Du_Qinglin_0001.jpg
# Img: lfw/Carla_Myers/Carla_Myers_0002.jpg
# Img: lfw/Juan_Carlos_Ferrero/Juan_Carlos_Ferrero_0022.jpg
# Img: lfw/Juan_Carlos_Ferrero/Juan_Carlos_Ferrero_0001.jpg
# Img: lfw/Lima_Azimi/Lima_Azimi_0001.jpg
# Img: lfw/Dunn_Lampton/Dunn_Lampton_0001.jpg
# Img: lfw/Colin_Powell/Colin_Powell_0100.jpg
# Img: lfw/Evander_Holyfield/Evander_Holyfield_0001.jpg
# Img: lfw/Paul_Greengrass/Paul_Greengrass_0001.jpg
# Img: lfw/Laurent_Woulzy/Laurent_Woulzy_0001.jpg
# Img: lfw/Jean_Chretien/Jean_Chretien_0011.jpg
# Img: lfw/Jason_Kidd/Jason_Kidd_0009.jpg
# Img: lfw/Gloria_Trevi/Gloria_Trevi_0001.jpg
# Img: lfw/Eve_Pelletier/Eve_Pelletier_0001.jpg
# Img: lfw/Desmon_Farmer/Desmon_Farmer_0001.jpg
# Img: lfw/Ewan_McGregor/Ewan_McGregor_0001.jpg
# Img: lfw/George_W_Bush/George_W_Bush_0342.jpg
# Img: lfw/Elizabeth_Dole/Elizabeth_Dole_0002.jpg
# Img: lfw/Kristanna_Loken/Kristanna_Loken_0001.jpg
# Img: lfw/Camilla_Parker_Bowles/Camilla_Parker_Bowles_0001.jpg
# Img: lfw/Jean_Chretien/Jean_Chretien_0047.jpg
# Img: lfw/Ariel_Sharon/Ariel_Sharon_0013.jpg
# Img: lfw/Jay_Garner/Jay_Garner_0001.jpg
# Img: lfw/Kim_Clijsters/Kim_Clijsters_0009.jpg
# Img: lfw/Tiger_Woods/Tiger_Woods_0019.jpg
# Img: lfw/Tom_Foy/Tom_Foy_0001.jpg
# Img: lfw/Colin_Powell/Colin_Powell_0068.jpg
# Img: lfw/Anthony_Rackauckas/Anthony_Rackauckas_0001.jpg
# Img: lfw/John_McCain/John_McCain_0003.jpg
# Img: lfw/Ray_Nagin/Ray_Nagin_0002.jpg
# Img: lfw/Vladimir_Putin/Vladimir_Putin_0038.jpg
# Img: lfw/Alvaro_Uribe/Alvaro_Uribe_0031.jpg
# Img: lfw/Steve_Mariucci/Steve_Mariucci_0002.jpg
# Img: lfw/John_Negroponte/John_Negroponte_0027.jpg
# Img: lfw/Naomi_Watts/Naomi_Watts_0019.jpg
# Img: lfw/Helen_Clark/Helen_Clark_0003.jpg
# Img: lfw/Bobby_Robson/Bobby_Robson_0001.jpg
# Img: lfw/Ellen_DeGeneres/Ellen_DeGeneres_0002.jpg
# Img: lfw/Colin_Powell/Colin_Powell_0180.jpg
# Img: lfw/Juan_Carlos_Morales/Juan_Carlos_Morales_0001.jpg
# Img: lfw/Roman_Polanski/Roman_Polanski_0004.jpg
# Img: lfw/Patrick_Leahy/Patrick_Leahy_0002.jpg
# Img: lfw/Daniel_Barenboim/Daniel_Barenboim_0001.jpg
# Img: lfw/Alyson_Hannigan/Alyson_Hannigan_0001.jpg
# Img: lfw/Oswaldo_Paya/Oswaldo_Paya_0002.jpg
# Img: lfw/Garth_Drabinsky/Garth_Drabinsky_0001.jpg
# Img: lfw/Julianne_Moore/Julianne_Moore_0013.jpg
# Img: lfw/Jan_Ullrich/Jan_Ullrich_0006.jpg
# Img: lfw/Kim_Clijsters/Kim_Clijsters_0011.jpg
# Img: lfw/Michael_Bloomberg/Michael_Bloomberg_0016.jpg
# Img: lfw/Adam_Ant/Adam_Ant_0001.jpg
# Img: lfw/Griffin_Colvin/Griffin_Colvin_0001.jpg
# Img: lfw/Nicanor_Duarte_Frutos/Nicanor_Duarte_Frutos_0007.jpg
# Img: lfw/Donatella_Versace/Donatella_Versace_0003.jpg
# Img: lfw/Roy_Blunt/Roy_Blunt_0001.jpg
# Img: lfw/Brittany_Snow/Brittany_Snow_0001.jpg
# Img: lfw/George_W_Bush/George_W_Bush_0387.jpg
# Img: lfw/Giuseppe_Gibilisco/Giuseppe_Gibilisco_0002.jpg
# Img: lfw/Bill_Gates/Bill_Gates_0007.jpg
# Img: lfw/Lindsay_Davenport/Lindsay_Davenport_0010.jpg
# Img: lfw/Tony_Blair/Tony_Blair_0084.jpg
# Img: lfw/Hosni_Mubarak/Hosni_Mubarak_0004.jpg
# Img: lfw/Rupert_Grint/Rupert_Grint_0001.jpg
# Img: lfw/Aaron_Sorkin/Aaron_Sorkin_0002.jpg
# Img: lfw/Sergei_Yastrzhembsky/Sergei_Yastrzhembsky_0001.jpg
# Img: lfw/Fidel_Castro/Fidel_Castro_0008.jpg
# Img: lfw/Faye_Wong/Faye_Wong_0001.jpg
# Img: lfw/Serena_Williams/Serena_Williams_0019.jpg
# Img: lfw/George_W_Bush/George_W_Bush_0382.jpg
# Img: lfw/Jerry_Springer/Jerry_Springer_0004.jpg
# Img: lfw/Lin_Yi-fu/Lin_Yi-fu_0001.jpg
# Img: lfw/Tim_Curley/Tim_Curley_0001.jpg
# Img: lfw/Rafael_Bielsa/Rafael_Bielsa_0001.jpg
# Img: lfw/Angela_Bassett/Angela_Bassett_0005.jpg
# Img: lfw/Hugo_Chavez/Hugo_Chavez_0015.jpg
# Img: lfw/Pierce_Brosnan/Pierce_Brosnan_0004.jpg
# Img: lfw/Syed_Abdul_Rahman_Geelani/Syed_Abdul_Rahman_Geelani_0001.jpg
# Img: lfw/Michelle_Hofland/Michelle_Hofland_0001.jpg
# Img: lfw/Emma_Thompson/Emma_Thompson_0003.jpg
# Img: lfw/Paulo_Cesar_Pinheiro/Paulo_Cesar_Pinheiro_0002.jpg
# Img: lfw/Ariel_Sharon/Ariel_Sharon_0021.jpg
# Img: lfw/Jim_Haslett/Jim_Haslett_0001.jpg
# Img: lfw/Enrik_Vendt/Enrik_Vendt_0001.jpg
# Img: lfw/George_W_Bush/George_W_Bush_0002.jpg
# Img: lfw/George_W_Bush/George_W_Bush_0251.jpg
# Img: lfw/Ernie_Harwell/Ernie_Harwell_0001.jpg
# Img: lfw/Tony_Blair/Tony_Blair_0051.jpg
# Img: lfw/Jean_Chretien/Jean_Chretien_0054.jpg
# Img: lfw/Kathleen_Kennedy_Townsend/Kathleen_Kennedy_Townsend_0001.jpg
# Img: lfw/Mike_Myers/Mike_Myers_0006.jpg
# Img: lfw/Lleyton_Hewitt/Lleyton_Hewitt_0039.jpg
# Img: lfw/Tim_Duncan/Tim_Duncan_0003.jpg
# Img: lfw/King_Abdullah_II/King_Abdullah_II_0004.jpg
# Img: lfw/Wolfgang_Clement/Wolfgang_Clement_0001.jpg
# Img: lfw/Marc_Grossman/Marc_Grossman_0001.jpg
# Img: lfw/Tom_Reilly/Tom_Reilly_0001.jpg
# Img: lfw/Richard_Dreyfuss/Richard_Dreyfuss_0001.jpg
# Img: lfw/Luiz_Inacio_Lula_da_Silva/Luiz_Inacio_Lula_da_Silva_0016.jpg
# Img: lfw/John_Kerry/John_Kerry_0007.jpg
# Img: lfw/Mohammed_Dahlan/Mohammed_Dahlan_0001.jpg
# Img: lfw/Art_Howe/Art_Howe_0004.jpg
# Img: lfw/Silvio_Fernandez/Silvio_Fernandez_0001.jpg
# Img: lfw/Constance_Marie/Constance_Marie_0002.jpg
# Img: lfw/Kurt_Tanabe/Kurt_Tanabe_0001.jpg
# Img: lfw/Larry_Thompson/Larry_Thompson_0001.jpg
# Img: lfw/David_Beckham/David_Beckham_0007.jpg
# Img: lfw/Ellen_Martin/Ellen_Martin_0001.jpg
# Img: lfw/Michael_Bloomberg/Michael_Bloomberg_0007.jpg
# Img: lfw/Hamid_Karzai/Hamid_Karzai_0010.jpg
# Img: lfw/Rod_Blagojevich/Rod_Blagojevich_0002.jpg
# Img: lfw/Ismail_Cem/Ismail_Cem_0001.jpg
# Img: lfw/Lleyton_Hewitt/Lleyton_Hewitt_0004.jpg
# Img: lfw/Jean_Chretien/Jean_Chretien_0018.jpg
# Img: lfw/George_W_Bush/George_W_Bush_0241.jpg
# Img: lfw/Michael_Patrick_King/Michael_Patrick_King_0001.jpg
# Img: lfw/Juan_Carlos_Ferrero/Juan_Carlos_Ferrero_0005.jpg
# Img: lfw/James_Morris/James_Morris_0001.jpg
# Img: lfw/Diana_Krall/Diana_Krall_0001.jpg
# Img: lfw/Janet_Leigh/Janet_Leigh_0001.jpg
# Img: lfw/Catherine_Zeta-Jones/Catherine_Zeta-Jones_0001.jpg
# Img: lfw/Benedita_da_Silva/Benedita_da_Silva_0001.jpg
# Img: lfw/Vaclav_Havel/Vaclav_Havel_0002.jpg
# Img: lfw/Steve_Wariner/Steve_Wariner_0001.jpg
# Img: lfw/Susilo_Bambang_Yudhoyono/Susilo_Bambang_Yudhoyono_0001.jpg
# Img: lfw/Mariana_Pollack/Mariana_Pollack_0001.jpg
# Img: lfw/Abdel_Nasser_Assidi/Abdel_Nasser_Assidi_0001.jpg
# Img: lfw/Sam_Torrance/Sam_Torrance_0002.jpg
# Img: lfw/Jennifer_Keller/Jennifer_Keller_0004.jpg
# Img: lfw/Alejandro_Avila/Alejandro_Avila_0001.jpg
# Img: lfw/Hestrie_Cloette/Hestrie_Cloette_0001.jpg
# Img: lfw/Erika_Harold/Erika_Harold_0003.jpg
# Img: lfw/Meryl_Streep/Meryl_Streep_0014.jpg
# Img: lfw/Tara_Dawn_Christensen/Tara_Dawn_Christensen_0001.jpg
# Img: lfw/Edmund_Hillary/Edmund_Hillary_0003.jpg
# Img: lfw/Nathalia_Gillot/Nathalia_Gillot_0001.jpg
# Img: lfw/Colin_Farrell/Colin_Farrell_0004.jpg
# Img: lfw/Tina_Conner/Tina_Conner_0001.jpg
# Img: lfw/Jerry_Falwell/Jerry_Falwell_0001.jpg
# Img: lfw/Tatsuya_Fuji/Tatsuya_Fuji_0001.jpg
# Img: lfw/Serena_Williams/Serena_Williams_0025.jpg
# Img: lfw/George_W_Bush/George_W_Bush_0265.jpg
# Img: lfw/William_Genego/William_Genego_0001.jpg
# Img: lfw/Mike_Tyson/Mike_Tyson_0003.jpg
# Img: lfw/Larry_Brown/Larry_Brown_0002.jpg
# Img: lfw/Michelle_Lecky/Michelle_Lecky_0001.jpg
# Img: lfw/Bill_McBride/Bill_McBride_0009.jpg
# Img: lfw/Gerhard_Schroeder/Gerhard_Schroeder_0004.jpg
# Img: lfw/Roy_Moore/Roy_Moore_0005.jpg
# Img: lfw/Silvio_Berlusconi/Silvio_Berlusconi_0023.jpg
# Img: lfw/Nicole_Kidman/Nicole_Kidman_0016.jpg
# Img: lfw/Kurt_Warner/Kurt_Warner_0003.jpg
# Img: lfw/Arnold_Schwarzenegger/Arnold_Schwarzenegger_0042.jpg
# Img: lfw/Justin_Timberlake/Justin_Timberlake_0002.jpg
# Img: lfw/Mohammad_Khatami/Mohammad_Khatami_0008.jpg
# Img: lfw/Ariel_Sharon/Ariel_Sharon_0062.jpg
# Img: lfw/Catherine_Zeta-Jones/Catherine_Zeta-Jones_0007.jpg
# Img: lfw/Boris_Trajkovski/Boris_Trajkovski_0001.jpg
# Img: lfw/George_W_Bush/George_W_Bush_0161.jpg
# Img: lfw/Andrzej_Tyszkiewicz/Andrzej_Tyszkiewicz_0001.jpg
# Img: lfw/Maria_Burks/Maria_Burks_0001.jpg
# Img: lfw/Jada_Pinkett_Smith/Jada_Pinkett_Smith_0001.jpg
# Img: lfw/Amelie_Mauresmo/Amelie_Mauresmo_0013.jpg
# Img: lfw/Paul_Henderson/Paul_Henderson_0001.jpg
# Img: lfw/Bob_Hope/Bob_Hope_0006.jpg
# Img: lfw/Colin_Powell/Colin_Powell_0168.jpg
# Img: lfw/Vincent_Brooks/Vincent_Brooks_0002.jpg
# Img: lfw/Jay_Rasulo/Jay_Rasulo_0002.jpg
# Img: lfw/John_Bolton/John_Bolton_0003.jpg
# Img: lfw/John_Rigas/John_Rigas_0001.jpg
# Img: lfw/Ricardo_Lagos/Ricardo_Lagos_0002.jpg
# Img: lfw/Winona_Ryder/Winona_Ryder_0011.jpg
# Img: lfw/Vicente_Fox/Vicente_Fox_0018.jpg
# Img: lfw/Astrid_Betancourt/Astrid_Betancourt_0001.jpg
# Img: lfw/Hugo_Chavez/Hugo_Chavez_0022.jpg
# Img: lfw/Philippe_Noiret/Philippe_Noiret_0001.jpg
# Img: lfw/Vitali_Klitschko/Vitali_Klitschko_0004.jpg
# Img: lfw/Heinz_Feldmann/Heinz_Feldmann_0003.jpg
# Img: lfw/Michael_Bloomberg/Michael_Bloomberg_0012.jpg
# Img: lfw/Binyamin_Ben-Eliezer/Binyamin_Ben-Eliezer_0001.jpg
# Img: lfw/Michael_Leavitt/Michael_Leavitt_0002.jpg
# Img: lfw/Georgina_Bardach/Georgina_Bardach_0001.jpg
# Img: lfw/George_W_Bush/George_W_Bush_0203.jpg
# Img: lfw/Lance_Armstrong/Lance_Armstrong_0004.jpg
# Img: lfw/Reese_Witherspoon/Reese_Witherspoon_0004.jpg
# Img: lfw/Mark_Geragos/Mark_Geragos_0001.jpg
# Img: lfw/Jennifer_Capriati/Jennifer_Capriati_0020.jpg
# Img: lfw/Yoriko_Kawaguchi/Yoriko_Kawaguchi_0009.jpg
# Img: lfw/Gerhard_Schroeder/Gerhard_Schroeder_0017.jpg
# Img: lfw/Sergey_Lavrov/Sergey_Lavrov_0005.jpg
# Img: lfw/Tippi_Hedren/Tippi_Hedren_0001.jpg
# Img: lfw/Razali_Ismail/Razali_Ismail_0001.jpg
# Img: lfw/Martin_Burnham/Martin_Burnham_0001.jpg
# Img: lfw/Juan_Roman_Riquelme/Juan_Roman_Riquelme_0001.jpg
# Img: lfw/Mel_Brooks/Mel_Brooks_0001.jpg
# Img: lfw/Trent_Lott/Trent_Lott_0012.jpg
# Img: lfw/Michael_Jordan/Michael_Jordan_0004.jpg
# Img: lfw/David_Braley/David_Braley_0001.jpg
# Img: lfw/Eliane_Karp/Eliane_Karp_0004.jpg
# Img: lfw/Eduardo_Duhalde/Eduardo_Duhalde_0014.jpg
# Img: lfw/Gene_Robinson/Gene_Robinson_0002.jpg
# Img: lfw/Mohammad_Aktar/Mohammad_Aktar_0001.jpg
# Img: lfw/Aung_San_Suu_Kyi/Aung_San_Suu_Kyi_0002.jpg
# Img: lfw/Jacques_Chirac/Jacques_Chirac_0049.jpg
# Img: lfw/Gerhard_Schroeder/Gerhard_Schroeder_0045.jpg
# Img: lfw/Eddie_Lucio/Eddie_Lucio_0001.jpg
# Img: lfw/Christina_Aguilera/Christina_Aguilera_0002.jpg
# Img: lfw/Donald_Rumsfeld/Donald_Rumsfeld_0091.jpg
# Img: lfw/Julianne_Moore/Julianne_Moore_0018.jpg
# Img: lfw/Laurence_Fishburne/Laurence_Fishburne_0001.jpg
# Img: lfw/Jose_Maria_Aznar/Jose_Maria_Aznar_0015.jpg
# Img: lfw/Christine_Baumgartner/Christine_Baumgartner_0003.jpg
# Img: lfw/Hans_Blix/Hans_Blix_0012.jpg
# Img: lfw/Victoria_Beckham/Victoria_Beckham_0003.jpg
# Img: lfw/Dinora_Rosales/Dinora_Rosales_0001.jpg
# Img: lfw/Juan_Carlos_Ferrero/Juan_Carlos_Ferrero_0027.jpg
# Img: lfw/Mathias_Reichhold/Mathias_Reichhold_0003.jpg
# Img: lfw/Sonia_Gandhi/Sonia_Gandhi_0004.jpg
# Img: lfw/Gray_Davis/Gray_Davis_0022.jpg
# Img: lfw/Mark_Mulder/Mark_Mulder_0001.jpg
# Img: lfw/Ozzy_Osbourne/Ozzy_Osbourne_0003.jpg
# Img: lfw/Kevin_Spacey/Kevin_Spacey_0002.jpg
# Img: lfw/Brad_Johnson/Brad_Johnson_0004.jpg
# Img: lfw/Tom_Ridge/Tom_Ridge_0031.jpg
# Img: lfw/Bonnie_Hunt/Bonnie_Hunt_0001.jpg
# Img: lfw/Takenori_Kanzaki/Takenori_Kanzaki_0001.jpg
# Img: lfw/Asa_Hutchinson/Asa_Hutchinson_0002.jpg
# Img: lfw/Pete_Sampras/Pete_Sampras_0021.jpg
# Img: lfw/Gerhard_Schroeder/Gerhard_Schroeder_0020.jpg
# Img: lfw/Tony_Blair/Tony_Blair_0029.jpg
# Img: lfw/Wang_Yingfan/Wang_Yingfan_0001.jpg
# Img: lfw/Marcus_Gronholm/Marcus_Gronholm_0001.jpg
# Img: lfw/Jean_Charest/Jean_Charest_0007.jpg
# Img: lfw/Jolanta_Kwasniewski/Jolanta_Kwasniewski_0002.jpg
# Img: lfw/William_Webster/William_Webster_0001.jpg
# Img: lfw/Drew_Gooden/Drew_Gooden_0001.jpg
# Img: lfw/Alejandro_Toledo/Alejandro_Toledo_0039.jpg
# Img: lfw/Salma_Hayek/Salma_Hayek_0012.jpg
# Img: lfw/Jean_Chretien/Jean_Chretien_0013.jpg
# Img: lfw/Vladimir_Putin/Vladimir_Putin_0019.jpg
# Img: lfw/George_Karl/George_Karl_0002.jpg
# Img: lfw/Eliza_Dushku/Eliza_Dushku_0001.jpg
# Img: lfw/John_Negroponte/John_Negroponte_0025.jpg
# Img: lfw/Benjamin_Netanyahu/Benjamin_Netanyahu_0005.jpg
# Img: lfw/Jesse_Jackson/Jesse_Jackson_0008.jpg
# Img: lfw/Jeong_Se-hyun/Jeong_Se-hyun_0005.jpg
# Img: lfw/George_W_Bush/George_W_Bush_0124.jpg
# Img: lfw/Hans_Blix/Hans_Blix_0022.jpg
# Img: lfw/Halle_Berry/Halle_Berry_0003.jpg
# Img: lfw/Donald_Rumsfeld/Donald_Rumsfeld_0070.jpg
# Img: lfw/Cruz_Bustamante/Cruz_Bustamante_0003.jpg
# Img: lfw/Keith_Fotta/Keith_Fotta_0001.jpg
# Img: lfw/John_Ashcroft/John_Ashcroft_0029.jpg
# Img: lfw/Spencer_Abraham/Spencer_Abraham_0017.jpg
# Img: lfw/Mohamed_ElBaradei/Mohamed_ElBaradei_0008.jpg
# Img: lfw/George_W_Bush/George_W_Bush_0216.jpg
# Img: lfw/Fran_Drescher/Fran_Drescher_0001.jpg
# Img: lfw/John_Negroponte/John_Negroponte_0023.jpg
# Img: lfw/George_W_Bush/George_W_Bush_0185.jpg
# Img: lfw/Marsha_Thomason/Marsha_Thomason_0001.jpg
# Img: lfw/Naomi_Watts/Naomi_Watts_0014.jpg
# Img: lfw/Tom_Moss/Tom_Moss_0001.jpg
# Img: lfw/Yoshiyuki_Kamei/Yoshiyuki_Kamei_0001.jpg
# Img: lfw/Tony_Blair/Tony_Blair_0072.jpg
# Img: lfw/Tommy_Lasorda/Tommy_Lasorda_0001.jpg
# Img: lfw/Gloria_Macapagal_Arroyo/Gloria_Macapagal_Arroyo_0023.jpg
# Img: lfw/Hashim_Thaci/Hashim_Thaci_0002.jpg
# Img: lfw/George_W_Bush/George_W_Bush_0478.jpg
# Img: lfw/George_Lopez/George_Lopez_0001.jpg
# Img: lfw/Ferenc_Madl/Ferenc_Madl_0001.jpg
# Img: lfw/Hugo_Chavez/Hugo_Chavez_0021.jpg
# Img: lfw/George_W_Bush/George_W_Bush_0225.jpg
# Img: lfw/Noelle_Bush/Noelle_Bush_0001.jpg
# Img: lfw/Fabricio_Oberto/Fabricio_Oberto_0001.jpg
# Img: lfw/Donald_Pettit/Donald_Pettit_0002.jpg
# Img: lfw/Gerhard_Schroeder/Gerhard_Schroeder_0011.jpg
# Img: lfw/Gerald_Barbarito/Gerald_Barbarito_0001.jpg
# Img: lfw/George_W_Bush/George_W_Bush_0292.jpg
# Img: lfw/Nick_Nolte/Nick_Nolte_0002.jpg
# Img: lfw/George_W_Bush/George_W_Bush_0350.jpg
# Img: lfw/Bob_Dole/Bob_Dole_0002.jpg
# Img: lfw/Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0018.jpg
# Img: lfw/George_W_Bush/George_W_Bush_0423.jpg
# Img: lfw/Ralf_Schumacher/Ralf_Schumacher_0004.jpg
# Img: lfw/Billy_Donovan/Billy_Donovan_0001.jpg
# Img: lfw/Juan_Carlos_Ferrero/Juan_Carlos_Ferrero_0019.jpg
# Img: lfw/Morgan_Fairchild/Morgan_Fairchild_0001.jpg
# Img: lfw/Mario_Cipollini/Mario_Cipollini_0001.jpg
# Img: lfw/Michael_Schumacher/Michael_Schumacher_0015.jpg
# Img: lfw/Lauren_Hutton/Lauren_Hutton_0002.jpg
# Img: lfw/Rick_Reed/Rick_Reed_0001.jpg
# Img: lfw/Colin_Powell/Colin_Powell_0032.jpg
# Img: lfw/Woody_Allen/Woody_Allen_0002.jpg
# Img: lfw/Eric_Taino/Eric_Taino_0001.jpg
# Img: lfw/Hamid_Karzai/Hamid_Karzai_0015.jpg
# Img: lfw/Darrell_Porter/Darrell_Porter_0002.jpg
# Img: lfw/Hassan_Nasrallah/Hassan_Nasrallah_0002.jpg
# Img: lfw/Natalie_Coughlin/Natalie_Coughlin_0006.jpg
# Img: lfw/Joan_Laporta/Joan_Laporta_0006.jpg
# Img: lfw/Saddam_Hussein/Saddam_Hussein_0002.jpg
# Img: lfw/Mohamed_ElBaradei/Mohamed_ElBaradei_0007.jpg
# Img: lfw/Terunobu_Maeda/Terunobu_Maeda_0001.jpg
# Img: lfw/Jose_Maria_Aznar/Jose_Maria_Aznar_0020.jpg
# Img: lfw/Jeannette_Biedermann/Jeannette_Biedermann_0001.jpg
# Img: lfw/John_Kerry/John_Kerry_0015.jpg
# Img: lfw/Robert_Duvall/Robert_Duvall_0004.jpg
# Img: lfw/Richard_Cohen/Richard_Cohen_0001.jpg
# Img: lfw/Donald_Rumsfeld/Donald_Rumsfeld_0109.jpg
# Img: lfw/Alejandro_Toledo/Alejandro_Toledo_0006.jpg
# Img: lfw/Vladimir_Putin/Vladimir_Putin_0001.jpg
# Img: lfw/Donald_Rumsfeld/Donald_Rumsfeld_0048.jpg
# Img: lfw/Tony_Blair/Tony_Blair_0070.jpg
# Img: lfw/Antonio_Palocci/Antonio_Palocci_0005.jpg
# Img: lfw/Arnaud_Lagardere/Arnaud_Lagardere_0001.jpg
# Img: lfw/Marco_Archer_Cardoso_Moreira/Marco_Archer_Cardoso_Moreira_0001.jpg
# Img: lfw/Arnold_Schwarzenegger/Arnold_Schwarzenegger_0038.jpg
# Img: lfw/Mary_Descenza/Mary_Descenza_0001.jpg
# Img: lfw/Rohman_al-Ghozi/Rohman_al-Ghozi_0001.jpg
# Img: lfw/Shinzo_Abe/Shinzo_Abe_0001.jpg
# Img: lfw/Vinnie_Jones/Vinnie_Jones_0001.jpg
# Img: lfw/Amber_Tamblyn/Amber_Tamblyn_0002.jpg
# Img: lfw/Marc-Andre_Fleury/Marc-Andre_Fleury_0001.jpg
# Img: lfw/Kathryn_Grayson/Kathryn_Grayson_0001.jpg
# Img: lfw/Amelie_Mauresmo/Amelie_Mauresmo_0008.jpg
# Img: lfw/David_Trimble/David_Trimble_0003.jpg
# Img: lfw/Alex_King/Alex_King_0001.jpg
# Img: lfw/Frank_Keating/Frank_Keating_0001.jpg
# Img: lfw/Gene_Robinson/Gene_Robinson_0005.jpg
# Img: lfw/Tony_Blair/Tony_Blair_0042.jpg
# Img: lfw/Tiger_Woods/Tiger_Woods_0010.jpg
# Img: lfw/Kofi_Annan/Kofi_Annan_0018.jpg
# Img: lfw/Kiki_Vandeweghe/Kiki_Vandeweghe_0001.jpg
# Img: lfw/Gloria_Macapagal_Arroyo/Gloria_Macapagal_Arroyo_0029.jpg
# Img: lfw/George_W_Bush/George_W_Bush_0001.jpg
# Img: lfw/Colin_Powell/Colin_Powell_0160.jpg
# Img: lfw/Jennifer_Aniston/Jennifer_Aniston_0013.jpg
# Img: lfw/Colin_Powell/Colin_Powell_0131.jpg
# Img: lfw/Gerhard_Schroeder/Gerhard_Schroeder_0093.jpg
# Img: lfw/Colin_Powell/Colin_Powell_0091.jpg
# Img: lfw/Martin_ONeill/Martin_ONeill_0001.jpg
# Img: lfw/Bob_Stoops/Bob_Stoops_0001.jpg
# Img: lfw/Jack_Straw/Jack_Straw_0022.jpg
# Img: lfw/Melinda_Czink/Melinda_Czink_0001.jpg
# Img: lfw/Linus_Roache/Linus_Roache_0001.jpg
# Img: lfw/Dennis_Hastert/Dennis_Hastert_0005.jpg
# Img: lfw/James_Franco/James_Franco_0001.jpg
# Img: lfw/Tony_Curtis/Tony_Curtis_0002.jpg
# Img: lfw/Ronaldo_Luis_Nazario_de_Lima/Ronaldo_Luis_Nazario_de_Lima_0002.jpg
# Img: lfw/Naomi_Watts/Naomi_Watts_0004.jpg
# Img: lfw/Serena_Williams/Serena_Williams_0038.jpg
# Img: lfw/Rick_Carlisle/Rick_Carlisle_0003.jpg
# Img: lfw/George_W_Bush/George_W_Bush_0299.jpg
# Img: lfw/Normand_Legault/Normand_Legault_0001.jpg
# Img: lfw/David_Gest/David_Gest_0001.jpg
# Img: lfw/Roy_Chaderton/Roy_Chaderton_0001.jpg
# Img: lfw/Angela_Bassett/Angela_Bassett_0002.jpg
# Img: lfw/Nick_Rimando/Nick_Rimando_0001.jpg
# Img: lfw/Alvaro_Uribe/Alvaro_Uribe_0035.jpg
# Img: lfw/Sean_Astin/Sean_Astin_0002.jpg
# Img: lfw/Gary_Carter/Gary_Carter_0002.jpg
# Img: lfw/Prince_Harry/Prince_Harry_0001.jpg
# Img: lfw/Bulent_Ecevit/Bulent_Ecevit_0006.jpg
# Img: lfw/Jim_Thome/Jim_Thome_0001.jpg
# Img: lfw/Bill_Graham/Bill_Graham_0005.jpg
# Img: lfw/Phan_Van_Khai/Phan_Van_Khai_0003.jpg
# Img: lfw/Ray_Allen/Ray_Allen_0002.jpg
# Img: lfw/Chok_Tong_Goh/Chok_Tong_Goh_0002.jpg
# Img: lfw/Jesse_Ventura/Jesse_Ventura_0002.jpg
# Img: lfw/Andrew_Caldecott/Andrew_Caldecott_0001.jpg
# Img: lfw/Gray_Davis/Gray_Davis_0010.jpg
# Img: lfw/Jon_Gruden/Jon_Gruden_0003.jpg
# Img: lfw/Katja_Riemann/Katja_Riemann_0001.jpg
# Img: lfw/Harrison_Ford/Harrison_Ford_0010.jpg
# Img: lfw/John_Travolta/John_Travolta_0001.jpg
# Img: lfw/Tony_Blair/Tony_Blair_0033.jpg
# Img: lfw/Joseph_Biden/Joseph_Biden_0002.jpg
# Img: lfw/Tiger_Woods/Tiger_Woods_0018.jpg
# Img: lfw/Larry_Wilmore/Larry_Wilmore_0001.jpg
# Img: lfw/George_W_Bush/George_W_Bush_0162.jpg
# Img: lfw/Hugo_Chavez/Hugo_Chavez_0065.jpg
# Img: lfw/Joe_Nichols/Joe_Nichols_0002.jpg
# Img: lfw/Mel_Karmazin/Mel_Karmazin_0001.jpg
# Img: lfw/Jean_Chretien/Jean_Chretien_0050.jpg
# Img: lfw/Dawn_Staley/Dawn_Staley_0001.jpg
# Img: lfw/Leonardo_Del_Vecchio/Leonardo_Del_Vecchio_0001.jpg
# Img: lfw/Brian_Scalabrine/Brian_Scalabrine_0001.jpg
# Img: lfw/Jimmy_Lee/Jimmy_Lee_0001.jpg
# Img: lfw/Calbert_Cheaney/Calbert_Cheaney_0001.jpg
# Img: lfw/Grant_Hackett/Grant_Hackett_0005.jpg
# Img: lfw/Candice_Bergen/Candice_Bergen_0003.jpg
# Img: lfw/Faye_Alibocus/Faye_Alibocus_0001.jpg
# Img: lfw/Mike_Montgomery/Mike_Montgomery_0002.jpg
# Img: lfw/James_Hill/James_Hill_0001.jpg
# Img: lfw/Jean_Brumley/Jean_Brumley_0001.jpg
# Img: lfw/Anne_McLellan/Anne_McLellan_0002.jpg
# Img: lfw/Jorge_Valdano/Jorge_Valdano_0001.jpg
# Img: lfw/George_W_Bush/George_W_Bush_0316.jpg
# Img: lfw/Jean_Chretien/Jean_Chretien_0017.jpg
# Img: lfw/George_W_Bush/George_W_Bush_0118.jpg
# Img: lfw/Saparmurat_Niyazov/Saparmurat_Niyazov_0001.jpg
# Img: lfw/Zahir_Shah/Zahir_Shah_0001.jpg
# Img: lfw/Robert_Duvall/Robert_Duvall_0006.jpg
# Img: lfw/Bill_Sizemore/Bill_Sizemore_0002.jpg
# Img: lfw/Mike_Martz/Mike_Martz_0007.jpg
# Img: lfw/Rita_Wilson/Rita_Wilson_0004.jpg
# Img: lfw/Brandon_Inge/Brandon_Inge_0001.jpg
# Img: lfw/Nick_Rahall/Nick_Rahall_0001.jpg
# Img: lfw/Tony_Blair/Tony_Blair_0085.jpg
# Img: lfw/Colin_Powell/Colin_Powell_0057.jpg
# Img: lfw/Carla_Del_Ponte/Carla_Del_Ponte_0004.jpg
# Img: lfw/Rosa_Haywa_de_Condori/Rosa_Haywa_de_Condori_0001.jpg
# Img: lfw/Leonid_Kuchma/Leonid_Kuchma_0005.jpg
# Img: lfw/Gabriel_Batistuta/Gabriel_Batistuta_0002.jpg
# Img: lfw/Richard_Myers/Richard_Myers_0013.jpg
# Img: lfw/Estelle_Morris/Estelle_Morris_0001.jpg
# Img: lfw/Marc_Gold/Marc_Gold_0001.jpg
# Img: lfw/William_Macy/William_Macy_0003.jpg
# Img: lfw/Lindsay_Davenport/Lindsay_Davenport_0017.jpg
# Img: lfw/John_Ashcroft/John_Ashcroft_0001.jpg
# Img: lfw/Bill_Frist/Bill_Frist_0002.jpg
# Img: lfw/El_Hadji_Diouf/El_Hadji_Diouf_0001.jpg
# Img: lfw/George_W_Bush/George_W_Bush_0201.jpg
# Img: lfw/Dominique_de_Villepin/Dominique_de_Villepin_0002.jpg
# Img: lfw/Valentino_Rossi/Valentino_Rossi_0003.jpg
# Img: lfw/Hans_Blix/Hans_Blix_0004.jpg
# Img: lfw/Arnold_Schwarzenegger/Arnold_Schwarzenegger_0034.jpg
# Img: lfw/Martha_Lucia_Ramirez/Martha_Lucia_Ramirez_0001.jpg
# Img: lfw/Michael_Capellas/Michael_Capellas_0002.jpg
# Img: lfw/James_W_Kennedy/James_W_Kennedy_0001.jpg
# Img: lfw/Nestor_Kirchner/Nestor_Kirchner_0032.jpg
# Img: lfw/Davis_Love_III/Davis_Love_III_0001.jpg
# Img: lfw/Katie_Harman/Katie_Harman_0001.jpg
# Img: lfw/Dai_Bachtiar/Dai_Bachtiar_0001.jpg
# Img: lfw/George_W_Bush/George_W_Bush_0021.jpg
# Img: lfw/Nabil_Shaath/Nabil_Shaath_0001.jpg
# Img: lfw/George_W_Bush/George_W_Bush_0115.jpg
# Img: lfw/Gary_Leon_Ridgway/Gary_Leon_Ridgway_0001.jpg
# Img: lfw/George_W_Bush/George_W_Bush_0421.jpg
# Img: lfw/Denise_Johnson/Denise_Johnson_0001.jpg
# Img: lfw/Dita_Von_Tesse/Dita_Von_Tesse_0001.jpg
# Img: lfw/Lars_Von_Trier/Lars_Von_Trier_0002.jpg
# Img: lfw/Luis_Gonzalez_Macchi/Luis_Gonzalez_Macchi_0003.jpg
# Img: lfw/Wilbert_Elki_Meza_Majino/Wilbert_Elki_Meza_Majino_0001.jpg
# Img: lfw/David_Ballantyne/David_Ballantyne_0001.jpg
# Img: lfw/Ray_Romano/Ray_Romano_0008.jpg
# Img: lfw/Abid_Hamid_Mahmud_Al-Tikriti/Abid_Hamid_Mahmud_Al-Tikriti_0003.jpg
# Img: lfw/Alex_Penelas/Alex_Penelas_0002.jpg
# Img: lfw/Colin_Powell/Colin_Powell_0206.jpg
# Img: lfw/Goldie_Hawn/Goldie_Hawn_0002.jpg
# Img: lfw/Michael_Schumacher/Michael_Schumacher_0008.jpg
# Img: lfw/Oxana_Fedorova/Oxana_Fedorova_0001.jpg
# Img: lfw/Vanessa_Redgrave/Vanessa_Redgrave_0002.jpg
# Img: lfw/James_Spalding/James_Spalding_0001.jpg
# Img: lfw/Jonathan_Edwards/Jonathan_Edwards_0005.jpg
# Img: lfw/Xanana_Gusmao/Xanana_Gusmao_0002.jpg
# Img: lfw/Marina_Silva/Marina_Silva_0001.jpg
# Img: lfw/Placido_Domingo/Placido_Domingo_0003.jpg
# Img: lfw/George_W_Bush/George_W_Bush_0091.jpg
# Img: lfw/Joan_Laporta/Joan_Laporta_0003.jpg
# Img: lfw/Jim_Carrey/Jim_Carrey_0001.jpg
# Img: lfw/George_W_Bush/George_W_Bush_0092.jpg
# Img: lfw/Blythe_Danner/Blythe_Danner_0001.jpg
# Img: lfw/Marwan_Barghouthi/Marwan_Barghouthi_0001.jpg
# Img: lfw/Maria_Shriver/Maria_Shriver_0004.jpg
# Img: lfw/Junichiro_Koizumi/Junichiro_Koizumi_0008.jpg
# Img: lfw/Ben_Howland/Ben_Howland_0004.jpg
# Img: lfw/Mike_Webster/Mike_Webster_0001.jpg
# Img: lfw/Donald_Rumsfeld/Donald_Rumsfeld_0028.jpg
# Img: lfw/Hermann_Maier/Hermann_Maier_0002.jpg
# Img: lfw/Li_Peng/Li_Peng_0002.jpg
# Img: lfw/Adam_Sandler/Adam_Sandler_0002.jpg
# Img: lfw/Lyle_Lovett/Lyle_Lovett_0001.jpg
# Img: lfw/Sergio_Vieira_De_Mello/Sergio_Vieira_De_Mello_0001.jpg
# Img: lfw/Candie_Kung/Candie_Kung_0001.jpg
# Img: lfw/John_Edwards/John_Edwards_0003.jpg
# Img: lfw/Gloria_Macapagal_Arroyo/Gloria_Macapagal_Arroyo_0032.jpg
# Img: lfw/Urmila_Matondkar/Urmila_Matondkar_0001.jpg
# Img: lfw/Irina_Yatchenko/Irina_Yatchenko_0001.jpg
# Img: lfw/Roh_Moo-hyun/Roh_Moo-hyun_0024.jpg
# Img: lfw/Matt_Anderson/Matt_Anderson_0001.jpg
# Img: lfw/Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0007.jpg
# Img: lfw/Vladimir_Putin/Vladimir_Putin_0017.jpg
# Img: lfw/Colin_Powell/Colin_Powell_0124.jpg
# Img: lfw/Loretta_Lynn_Harper/Loretta_Lynn_Harper_0001.jpg
# Img: lfw/Marwan_Barghouthi/Marwan_Barghouthi_0002.jpg
# Img: lfw/Clive_Woodward/Clive_Woodward_0001.jpg
# Img: lfw/Abdullah/Abdullah_0002.jpg
# Img: lfw/Ian_Gillan/Ian_Gillan_0001.jpg
# Img: lfw/Hubie_Brown/Hubie_Brown_0001.jpg
# Img: lfw/Naomi_Hayashi/Naomi_Hayashi_0001.jpg
# Img: lfw/Missy_Crider/Missy_Crider_0001.jpg
# Img: lfw/Eric_Christian_Olsen/Eric_Christian_Olsen_0001.jpg
# Img: lfw/Serena_Williams/Serena_Williams_0051.jpg
# Img: lfw/Lesley_McCulloch/Lesley_McCulloch_0002.jpg
# Img: lfw/Kim_Clijsters/Kim_Clijsters_0002.jpg
# Img: lfw/Tian_Liang/Tian_Liang_0001.jpg
# Img: lfw/Sergio_Vieira_De_Mello/Sergio_Vieira_De_Mello_0011.jpg
# Img: lfw/Mia_Mottley/Mia_Mottley_0001.jpg
# Img: lfw/Niall_Connolly/Niall_Connolly_0001.jpg
# Img: lfw/George_W_Bush/George_W_Bush_0324.jpg
# Img: lfw/Steve_Austin/Steve_Austin_0001.jpg
# Img: lfw/Michael_Bolton/Michael_Bolton_0001.jpg
# Img: lfw/Serena_Williams/Serena_Williams_0026.jpg
# Img: lfw/Ashanti/Ashanti_0001.jpg
# Img: lfw/James_Kelly/James_Kelly_0009.jpg
# Img: lfw/Kristanna_Loken/Kristanna_Loken_0003.jpg
# Img: lfw/Sigourney_Weaver/Sigourney_Weaver_0001.jpg
# Img: lfw/Robert_Witt/Robert_Witt_0001.jpg
# Img: lfw/Jiri_Novak/Jiri_Novak_0002.jpg
# Img: lfw/Marta_Dominguz/Marta_Dominguz_0001.jpg
# Img: lfw/Hu_Jintao/Hu_Jintao_0006.jpg
# Img: lfw/George_W_Bush/George_W_Bush_0419.jpg
# Img: lfw/Clare_Short/Clare_Short_0003.jpg
# Img: lfw/Gray_Davis/Gray_Davis_0003.jpg
# Img: lfw/Miroljub/Miroljub_0001.jpg
# Img: lfw/Surya_Bahadur_Thapa/Surya_Bahadur_Thapa_0001.jpg
# Img: lfw/Kaio_Almeida/Kaio_Almeida_0001.jpg
# Img: lfw/Stephen_Frears/Stephen_Frears_0001.jpg
# Img: lfw/Bill_Clinton/Bill_Clinton_0008.jpg
# Img: lfw/George_W_Bush/George_W_Bush_0253.jpg
# Img: lfw/Leslie_Caldwell/Leslie_Caldwell_0002.jpg
# Img: lfw/Bode_Miller/Bode_Miller_0001.jpg
# Img: lfw/Carlos_Manuel_Pruneda/Carlos_Manuel_Pruneda_0003.jpg
# Img: lfw/Megawati_Sukarnoputri/Megawati_Sukarnoputri_0007.jpg
# Img: lfw/Donald_Rumsfeld/Donald_Rumsfeld_0013.jpg
# Img: lfw/Ralph_Fiennes/Ralph_Fiennes_0001.jpg
# Img: lfw/Rien_Long/Rien_Long_0001.jpg
# Img: lfw/George_W_Bush/George_W_Bush_0014.jpg
# Img: lfw/Tommy_Franks/Tommy_Franks_0006.jpg
# Img: lfw/Paulie_Ayala/Paulie_Ayala_0001.jpg
# Img: lfw/Hun_Sen/Hun_Sen_0004.jpg
# Img: lfw/Fidel_Castro/Fidel_Castro_0005.jpg
# Img: lfw/Rashid_Qureshi/Rashid_Qureshi_0001.jpg
# Img: lfw/Debbie_Allen/Debbie_Allen_0001.jpg
# Img: lfw/Albert_Montanes/Albert_Montanes_0001.jpg
# Img: lfw/Marisol_Martinez_Sambran/Marisol_Martinez_Sambran_0001.jpg
# Img: lfw/Willie_Wilson/Willie_Wilson_0001.jpg
# Img: lfw/John_Howard/John_Howard_0008.jpg
# Img: lfw/Yoko_Ono/Yoko_Ono_0005.jpg
# Img: lfw/George_W_Bush/George_W_Bush_0287.jpg
# Img: lfw/Stacey_Yamaguchi/Stacey_Yamaguchi_0001.jpg
# Img: lfw/Laura_Bush/Laura_Bush_0010.jpg
# Img: lfw/Stephane_Rochon/Stephane_Rochon_0001.jpg
# Img: lfw/Michael_Keaton/Michael_Keaton_0002.jpg
# Img: lfw/Zoran_Djindjic/Zoran_Djindjic_0001.jpg
# Img: lfw/Gil_de_Ferran/Gil_de_Ferran_0003.jpg
# Img: lfw/Rebecca_Romijn-Stamos/Rebecca_Romijn-Stamos_0002.jpg
# Img: lfw/Hillary_Clinton/Hillary_Clinton_0010.jpg
# Img: lfw/Mary_Anne_Souza/Mary_Anne_Souza_0001.jpg
# Img: lfw/Jaqueline_Godoy/Jaqueline_Godoy_0001.jpg
# Img: lfw/William_Rehnquist/William_Rehnquist_0002.jpg
# Img: lfw/Ray_Young/Ray_Young_0001.jpg
# Img: lfw/Keith_Tyson/Keith_Tyson_0001.jpg
# Img: lfw/Vincent_Brooks/Vincent_Brooks_0001.jpg
# Img: lfw/Ariel_Sharon/Ariel_Sharon_0001.jpg
# Img: lfw/Leslie_Ann_Woodward/Leslie_Ann_Woodward_0002.jpg
# Img: lfw/Cecilia_Cheung/Cecilia_Cheung_0001.jpg
# Img: lfw/Salman_Rushdie/Salman_Rushdie_0001.jpg
# Img: lfw/Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0016.jpg
# Img: lfw/Michael_Bloomberg/Michael_Bloomberg_0013.jpg
# Img: lfw/Ben_Curtis/Ben_Curtis_0003.jpg
# Img: lfw/Iain_Duncan_Smith/Iain_Duncan_Smith_0003.jpg
# Img: lfw/Agnelo_Queiroz/Agnelo_Queiroz_0001.jpg
# Img: lfw/Michael_Sullivan/Michael_Sullivan_0002.jpg
# Img: lfw/Richard_Virenque/Richard_Virenque_0004.jpg
# Img: lfw/Serena_Williams/Serena_Williams_0050.jpg
# Img: lfw/Jessica_Alba/Jessica_Alba_0001.jpg
# Img: lfw/Alexandra_Stevenson/Alexandra_Stevenson_0003.jpg
# Img: lfw/John_Travolta/John_Travolta_0002.jpg
# Img: lfw/Laurence_Tribe/Laurence_Tribe_0001.jpg
# Img: lfw/Cruz_Bustamante/Cruz_Bustamante_0002.jpg
# Img: lfw/Scott_Gorelick/Scott_Gorelick_0001.jpg
# Img: lfw/Andrew_Bunner/Andrew_Bunner_0002.jpg
# Img: lfw/OJ_Simpson/OJ_Simpson_0002.jpg
# Img: lfw/David_Hasselhoff/David_Hasselhoff_0001.jpg
# Img: lfw/Shannyn_Sossamon/Shannyn_Sossamon_0001.jpg
# Img: lfw/Bill_Gates/Bill_Gates_0001.jpg
# Img: lfw/Dolly_Parton/Dolly_Parton_0001.jpg
# Img: lfw/Ricky_Ponting/Ricky_Ponting_0001.jpg
# Img: lfw/Moby/Moby_0001.jpg
# Img: lfw/Courtney_Love/Courtney_Love_0001.jpg
# Img: lfw/Yossi_Beilin/Yossi_Beilin_0001.jpg
# Img: lfw/Gwendal_Peizerat/Gwendal_Peizerat_0003.jpg
# Img: lfw/Steven_Hatfill/Steven_Hatfill_0001.jpg
# Img: lfw/Rachel_Wadsworth/Rachel_Wadsworth_0001.jpg
# Img: lfw/Richard_Butler/Richard_Butler_0002.jpg
# Img: lfw/Laura_Bush/Laura_Bush_0014.jpg
# Img: lfw/Elaine_Chao/Elaine_Chao_0001.jpg
# Img: lfw/Glen_Clark/Glen_Clark_0001.jpg
# Img: lfw/Hun_Sen/Hun_Sen_0002.jpg
# Img: lfw/Tony_Blair/Tony_Blair_0088.jpg
# Img: lfw/Guillaume_Soro/Guillaume_Soro_0001.jpg
# Img: lfw/John_Negroponte/John_Negroponte_0020.jpg
# Img: lfw/Ari_Fleischer/Ari_Fleischer_0008.jpg
# Img: lfw/Leslie_Caldwell/Leslie_Caldwell_0003.jpg
# Img: lfw/Kim_Clijsters/Kim_Clijsters_0004.jpg
# Img: lfw/Alberto_Fujimori/Alberto_Fujimori_0002.jpg
# Img: lfw/Gray_Davis/Gray_Davis_0002.jpg
# Img: lfw/Emmy_Rossum/Emmy_Rossum_0001.jpg
# Img: lfw/Ratna_Sari_Dewi_Sukarno/Ratna_Sari_Dewi_Sukarno_0001.jpg
# Img: lfw/Li_Peng/Li_Peng_0009.jpg
# Img: lfw/Zhu_Rongji/Zhu_Rongji_0007.jpg
# Img: lfw/George_Robertson/George_Robertson_0010.jpg
# Img: lfw/Lou_Ye/Lou_Ye_0001.jpg
# Img: lfw/Eric_Clapton/Eric_Clapton_0002.jpg
# Img: lfw/George_W_Bush/George_W_Bush_0168.jpg
# Img: lfw/Jacques_Chirac/Jacques_Chirac_0017.jpg
# Img: lfw/Tony_Stewart/Tony_Stewart_0002.jpg
# Img: lfw/Bartosz_Kizierowski/Bartosz_Kizierowski_0001.jpg
# Img: lfw/Filippo_Inzaghi/Filippo_Inzaghi_0001.jpg
# Img: lfw/Hans_Blix/Hans_Blix_0013.jpg
# Img: lfw/Aung_San_Suu_Kyi/Aung_San_Suu_Kyi_0001.jpg
# Img: lfw/Julie_Gerberding/Julie_Gerberding_0006.jpg
# Img: lfw/George_W_Bush/George_W_Bush_0004.jpg
# Img: lfw/Robert_Blackwill/Robert_Blackwill_0001.jpg
# Img: lfw/Denzel_Washington/Denzel_Washington_0003.jpg
# Img: lfw/Mohammed_Al-Douri/Mohammed_Al-Douri_0007.jpg
# Img: lfw/David_Wolf/David_Wolf_0002.jpg
# Img: lfw/Baburam_Bhattari/Baburam_Bhattari_0001.jpg
# Img: lfw/Michael_Denzel/Michael_Denzel_0001.jpg
# Img: lfw/Mohammad_Khatami/Mohammad_Khatami_0010.jpg
# Img: lfw/Mike_Weir/Mike_Weir_0008.jpg
# Img: lfw/Condoleezza_Rice/Condoleezza_Rice_0009.jpg
# Img: lfw/Ignacio_Antonio_Velasco/Ignacio_Antonio_Velasco_0001.jpg
# Img: lfw/Luo_Linquan/Luo_Linquan_0001.jpg
# Img: lfw/Kevin_Costner/Kevin_Costner_0004.jpg
# Img: lfw/Clay_Aiken/Clay_Aiken_0005.jpg
# Img: lfw/Jay_Garner/Jay_Garner_0003.jpg
# Img: lfw/Dennis_Kozlowski/Dennis_Kozlowski_0001.jpg
# Img: lfw/Vivica_Fox/Vivica_Fox_0001.jpg
# Img: lfw/George_W_Bush/George_W_Bush_0298.jpg
# Img: lfw/Ariel_Sharon/Ariel_Sharon_0023.jpg
# Img: lfw/Marlene_Weingartner/Marlene_Weingartner_0001.jpg
# Img: lfw/Asif_Ali_Zardari/Asif_Ali_Zardari_0001.jpg
# Img: lfw/Vivica_Fox/Vivica_Fox_0002.jpg
# Img: lfw/Habib_Hisham/Habib_Hisham_0001.jpg
# Img: lfw/Walter_Mondale/Walter_Mondale_0006.jpg
# Img: lfw/John_Howard/John_Howard_0015.jpg
# Img: lfw/Hugo_Chavez/Hugo_Chavez_0016.jpg
# Img: lfw/Joschka_Fischer/Joschka_Fischer_0007.jpg
# Img: lfw/Roseanne_Barr/Roseanne_Barr_0002.jpg
# Img: lfw/Marcelo_Bielsa/Marcelo_Bielsa_0001.jpg
# Img: lfw/Jeremy_Shockey/Jeremy_Shockey_0001.jpg
# Img: lfw/Colin_Powell/Colin_Powell_0061.jpg
# Img: lfw/Meryl_Streep/Meryl_Streep_0004.jpg
# Img: lfw/Charles_Taylor/Charles_Taylor_0006.jpg
# Img: lfw/John_Ashcroft/John_Ashcroft_0030.jpg
# Img: lfw/Vladimir_Putin/Vladimir_Putin_0041.jpg
# Img: lfw/Garry_Trudeau/Garry_Trudeau_0002.jpg
# Img: lfw/Igor_Ivanov/Igor_Ivanov_0006.jpg
# Img: lfw/Eva_Herzigova/Eva_Herzigova_0001.jpg
# Img: lfw/Junichiro_Koizumi/Junichiro_Koizumi_0047.jpg
# Img: lfw/Richard_Barry/Richard_Barry_0001.jpg
# Img: lfw/Hugo_Chavez/Hugo_Chavez_0017.jpg
# Img: lfw/Jacques_Chirac/Jacques_Chirac_0013.jpg
# Img: lfw/James_Blake/James_Blake_0003.jpg
# Img: lfw/David_Bowie/David_Bowie_0001.jpg
# Img: lfw/Markus_Beyer/Markus_Beyer_0001.jpg
# Img: lfw/Peter_Bacanovic/Peter_Bacanovic_0001.jpg
# Img: lfw/Michelle_Yeoh/Michelle_Yeoh_0004.jpg
# Img: lfw/Megawati_Sukarnoputri/Megawati_Sukarnoputri_0033.jpg
# Img: lfw/Frank_Solich/Frank_Solich_0005.jpg
# Img: lfw/Steven_Van_Zandt/Steven_Van_Zandt_0001.jpg
# Img: lfw/Max_Biaggi/Max_Biaggi_0001.jpg
# Img: lfw/Abdullah/Abdullah_0004.jpg
# Img: lfw/Hoda_Asfor/Hoda_Asfor_0001.jpg
# Img: lfw/Lucy_Liu/Lucy_Liu_0001.jpg
# Img: lfw/Hans_Blix/Hans_Blix_0034.jpg
# Img: lfw/Giuseppe_Morchio/Giuseppe_Morchio_0001.jpg
# Img: lfw/Cherie_Blair/Cherie_Blair_0003.jpg
# Img: lfw/Kenneth_Bowersox/Kenneth_Bowersox_0001.jpg
# Img: lfw/Brian_Gregory/Brian_Gregory_0001.jpg
# Img: lfw/Ricardo_Lagos/Ricardo_Lagos_0008.jpg
# Img: lfw/Saeed_Anwar/Saeed_Anwar_0001.jpg
# Img: lfw/Brian_Campbell/Brian_Campbell_0001.jpg
# Img: lfw/Naomi_Watts/Naomi_Watts_0008.jpg
# Img: lfw/Debra_Shank/Debra_Shank_0001.jpg
# Img: lfw/Jane_Kaczmarek/Jane_Kaczmarek_0002.jpg
# Img: lfw/John_Bolton/John_Bolton_0008.jpg
# Img: lfw/Jean-Sebastien_Giguere/Jean-Sebastien_Giguere_0001.jpg
# Img: lfw/Erin_Runnion/Erin_Runnion_0004.jpg
# Img: lfw/Jose_Genoino/Jose_Genoino_0001.jpg
# Img: lfw/Patrik_Kristiansson/Patrik_Kristiansson_0001.jpg
# Img: lfw/Allyson_Felix/Allyson_Felix_0001.jpg
# Img: lfw/Michael_Rolinee/Michael_Rolinee_0001.jpg
# Img: lfw/Arnold_Schwarzenegger/Arnold_Schwarzenegger_0004.jpg
# Img: lfw/Kelly_Osbourne/Kelly_Osbourne_0001.jpg
# Img: lfw/Junichiro_Koizumi/Junichiro_Koizumi_0051.jpg
# Img: lfw/Judy_Genshaft/Judy_Genshaft_0001.jpg
# Img: lfw/Don_Nickles/Don_Nickles_0001.jpg
# Img: lfw/Eduardo_Duhalde/Eduardo_Duhalde_0013.jpg
# Img: lfw/Christine_Todd_Whitman/Christine_Todd_Whitman_0001.jpg
# Img: lfw/Saddam_Hussein/Saddam_Hussein_0020.jpg
# ...
# Img: dogImages/train/073.German_wirehaired_pointer/German_wirehaired_pointer_05068.jpg
# Img: dogImages/train/107.Norfolk_terrier/Norfolk_terrier_07073.jpg
# Img: dogImages/train/129.Tibetan_mastiff/Tibetan_mastiff_08155.jpg
# Img: dogImages/train/011.Australian_cattle_dog/Australian_cattle_dog_00777.jpg
# Img: dogImages/train/104.Miniature_schnauzer/Miniature_schnauzer_06928.jpg
# Img: dogImages/train/074.Giant_schnauzer/Giant_schnauzer_05095.jpg
# Img: dogImages/train/111.Norwich_terrier/Norwich_terrier_07268.jpg
# Img: dogImages/train/020.Belgian_malinois/Belgian_malinois_01454.jpg
# Img: dogImages/train/124.Poodle/Poodle_07950.jpg
# Img: dogImages/train/109.Norwegian_elkhound/Norwegian_elkhound_07172.jpg
# Img: dogImages/train/129.Tibetan_mastiff/Tibetan_mastiff_08172.jpg
# Img: dogImages/train/046.Cavalier_king_charles_spaniel/Cavalier_king_charles_spaniel_03255.jpg
# Img: dogImages/train/049.Chinese_crested/Chinese_crested_03470.jpg
# Img: dogImages/train/068.Flat-coated_retriever/Flat-coated_retriever_04731.jpg
# Img: dogImages/train/095.Kuvasz/Kuvasz_06398.jpg
# Img: dogImages/train/112.Nova_scotia_duck_tolling_retriever/Nova_scotia_duck_tolling_retriever_07308.jpg
# Img: dogImages/train/080.Greater_swiss_mountain_dog/Greater_swiss_mountain_dog_05488.jpg
# Img: dogImages/train/118.Pembroke_welsh_corgi/Pembroke_welsh_corgi_07649.jpg
# Img: dogImages/train/031.Borzoi/Borzoi_02177.jpg
# Img: dogImages/train/040.Bulldog/Bulldog_02856.jpg
# Img: dogImages/train/094.Komondor/Komondor_06381.jpg
# Img: dogImages/train/053.Cocker_spaniel/Cocker_spaniel_03785.jpg
# Img: dogImages/train/076.Golden_retriever/Golden_retriever_05205.jpg
# Img: dogImages/train/001.Affenpinscher/Affenpinscher_00027.jpg
# Img: dogImages/train/004.Akita/Akita_00273.jpg
# Img: dogImages/train/050.Chinese_shar-pei/Chinese_shar-pei_03578.jpg
# Img: dogImages/train/034.Boxer/Boxer_02389.jpg
# Img: dogImages/train/098.Leonberger/Leonberger_06563.jpg
# Img: dogImages/train/074.Giant_schnauzer/Giant_schnauzer_05114.jpg
# Img: dogImages/train/060.Dogue_de_bordeaux/Dogue_de_bordeaux_04280.jpg
# Img: dogImages/train/122.Pointer/Pointer_07820.jpg
# Img: dogImages/train/078.Great_dane/Great_dane_05333.jpg
# Img: dogImages/train/004.Akita/Akita_00260.jpg
# Img: dogImages/train/062.English_setter/English_setter_04393.jpg
# Img: dogImages/train/041.Bullmastiff/Bullmastiff_02903.jpg
# Img: dogImages/train/120.Pharaoh_hound/Pharaoh_hound_07735.jpg
# Img: dogImages/train/011.Australian_cattle_dog/Australian_cattle_dog_00742.jpg
# Img: dogImages/train/098.Leonberger/Leonberger_06594.jpg
# Img: dogImages/train/031.Borzoi/Borzoi_02153.jpg
# Img: dogImages/train/033.Bouvier_des_flandres/Bouvier_des_flandres_02332.jpg
# Img: dogImages/train/009.American_water_spaniel/American_water_spaniel_00658.jpg
# Img: dogImages/train/041.Bullmastiff/Bullmastiff_02918.jpg
# Img: dogImages/train/008.American_staffordshire_terrier/American_staffordshire_terrier_00592.jpg
# Img: dogImages/train/103.Mastiff/Mastiff_06809.jpg
# Img: dogImages/train/122.Pointer/Pointer_07835.jpg
# Img: dogImages/train/049.Chinese_crested/Chinese_crested_03517.jpg
# Img: dogImages/train/107.Norfolk_terrier/Norfolk_terrier_07035.jpg
# Img: dogImages/train/016.Beagle/Beagle_01164.jpg
# Img: dogImages/train/034.Boxer/Boxer_02372.jpg
# Img: dogImages/train/048.Chihuahua/Chihuahua_03402.jpg
# Img: dogImages/train/109.Norwegian_elkhound/Norwegian_elkhound_07147.jpg
# Img: dogImages/train/026.Black_russian_terrier/Black_russian_terrier_01838.jpg
# Img: dogImages/train/097.Lakeland_terrier/Lakeland_terrier_06549.jpg
# Img: dogImages/train/052.Clumber_spaniel/Clumber_spaniel_03669.jpg
# Img: dogImages/train/034.Boxer/Boxer_02393.jpg
# Img: dogImages/train/016.Beagle/Beagle_01198.jpg
# Img: dogImages/train/026.Black_russian_terrier/Black_russian_terrier_01863.jpg
# Img: dogImages/train/001.Affenpinscher/Affenpinscher_00028.jpg
# Img: dogImages/train/020.Belgian_malinois/Belgian_malinois_01419.jpg
# Img: dogImages/train/039.Bull_terrier/Bull_terrier_02746.jpg
# Img: dogImages/train/092.Keeshond/Keeshond_06279.jpg
# Img: dogImages/train/057.Dalmatian/Dalmatian_04034.jpg
# Img: dogImages/train/027.Bloodhound/Bloodhound_01944.jpg
# Img: dogImages/train/091.Japanese_chin/Japanese_chin_06182.jpg
# Img: dogImages/train/029.Border_collie/Border_collie_02061.jpg
# Img: dogImages/train/052.Clumber_spaniel/Clumber_spaniel_03674.jpg
# Img: dogImages/train/062.English_setter/English_setter_04420.jpg
# Img: dogImages/train/046.Cavalier_king_charles_spaniel/Cavalier_king_charles_spaniel_03308.jpg
# Img: dogImages/train/095.Kuvasz/Kuvasz_06396.jpg
# Img: dogImages/train/039.Bull_terrier/Bull_terrier_02734.jpg
# Img: dogImages/train/089.Irish_wolfhound/Irish_wolfhound_06059.jpg
# Img: dogImages/train/069.French_bulldog/French_bulldog_04820.jpg
# Img: dogImages/train/042.Cairn_terrier/Cairn_terrier_02967.jpg
# Img: dogImages/train/004.Akita/Akita_00226.jpg
# Img: dogImages/train/100.Lowchen/Lowchen_06712.jpg
# Img: dogImages/train/025.Black_and_tan_coonhound/Black_and_tan_coonhound_01797.jpg
# Img: dogImages/train/071.German_shepherd_dog/German_shepherd_dog_04893.jpg
# Img: dogImages/train/087.Irish_terrier/Irish_terrier_05882.jpg
# Img: dogImages/train/055.Curly-coated_retriever/Curly-coated_retriever_03865.jpg
# Img: dogImages/train/103.Mastiff/Mastiff_06812.jpg
# Img: dogImages/train/041.Bullmastiff/Bullmastiff_02931.jpg
# Img: dogImages/train/115.Papillon/Papillon_07504.jpg
# Img: dogImages/train/115.Papillon/Papillon_07499.jpg
# Img: dogImages/train/058.Dandie_dinmont_terrier/Dandie_dinmont_terrier_04122.jpg
# Img: dogImages/train/002.Afghan_hound/Afghan_hound_00114.jpg
# Img: dogImages/train/014.Basenji/Basenji_00969.jpg
# Img: dogImages/train/011.Australian_cattle_dog/Australian_cattle_dog_00796.jpg
# Img: dogImages/train/101.Maltese/Maltese_06752.jpg
# Img: dogImages/train/126.Saint_bernard/Saint_bernard_08039.jpg
# Img: dogImages/train/044.Cane_corso/Cane_corso_03168.jpg
# Img: dogImages/train/044.Cane_corso/Cane_corso_03118.jpg
# Img: dogImages/train/021.Belgian_sheepdog/Belgian_sheepdog_01514.jpg
# Img: dogImages/train/103.Mastiff/Mastiff_06865.jpg
# Img: dogImages/train/108.Norwegian_buhund/Norwegian_buhund_07095.jpg
# Img: dogImages/train/099.Lhasa_apso/Lhasa_apso_06621.jpg
# Img: dogImages/train/005.Alaskan_malamute/Alaskan_malamute_00343.jpg
# Img: dogImages/train/020.Belgian_malinois/Belgian_malinois_01439.jpg
# Img: dogImages/train/099.Lhasa_apso/Lhasa_apso_06630.jpg
# Img: dogImages/train/120.Pharaoh_hound/Pharaoh_hound_07723.jpg
# Img: dogImages/train/097.Lakeland_terrier/Lakeland_terrier_06503.jpg
# Img: dogImages/train/005.Alaskan_malamute/Alaskan_malamute_00384.jpg
# Img: dogImages/train/036.Briard/Briard_02578.jpg
# Img: dogImages/train/091.Japanese_chin/Japanese_chin_06213.jpg
# Img: dogImages/train/076.Golden_retriever/Golden_retriever_05227.jpg
# Img: dogImages/train/104.Miniature_schnauzer/Miniature_schnauzer_06914.jpg
# Img: dogImages/train/046.Cavalier_king_charles_spaniel/Cavalier_king_charles_spaniel_03264.jpg
# Img: dogImages/train/079.Great_pyrenees/Great_pyrenees_05385.jpg
# Img: dogImages/train/049.Chinese_crested/Chinese_crested_03486.jpg
# Img: dogImages/train/117.Pekingese/Pekingese_07578.jpg
# Img: dogImages/train/035.Boykin_spaniel/Boykin_spaniel_02483.jpg
# Img: dogImages/train/122.Pointer/Pointer_07837.jpg
# Img: dogImages/train/016.Beagle/Beagle_01167.jpg
# Img: dogImages/train/122.Pointer/Pointer_07805.jpg
# Img: dogImages/train/129.Tibetan_mastiff/Tibetan_mastiff_08153.jpg
# Img: dogImages/train/077.Gordon_setter/Gordon_setter_05288.jpg
# Img: dogImages/train/111.Norwich_terrier/Norwich_terrier_07275.jpg
# Img: dogImages/train/119.Petit_basset_griffon_vendeen/Petit_basset_griffon_vendeen_07710.jpg
# Img: dogImages/train/061.English_cocker_spaniel/English_cocker_spaniel_04321.jpg
# Img: dogImages/train/093.Kerry_blue_terrier/Kerry_blue_terrier_06314.jpg
# Img: dogImages/train/086.Irish_setter/Irish_setter_05817.jpg
# Img: dogImages/train/042.Cairn_terrier/Cairn_terrier_03025.jpg
# Img: dogImages/train/116.Parson_russell_terrier/Parson_russell_terrier_07533.jpg
# Img: dogImages/train/107.Norfolk_terrier/Norfolk_terrier_07041.jpg
# Img: dogImages/train/043.Canaan_dog/Canaan_dog_03040.jpg
# Img: dogImages/train/004.Akita/Akita_00253.jpg
# Img: dogImages/train/052.Clumber_spaniel/Clumber_spaniel_03709.jpg
# Img: dogImages/train/036.Briard/Briard_02531.jpg
# Img: dogImages/train/082.Havanese/Havanese_05588.jpg
# Img: dogImages/train/017.Bearded_collie/Bearded_collie_01217.jpg
# Img: dogImages/train/029.Border_collie/Border_collie_02045.jpg
# Img: dogImages/train/043.Canaan_dog/Canaan_dog_03044.jpg
# Img: dogImages/train/014.Basenji/Basenji_01023.jpg
# Img: dogImages/train/035.Boykin_spaniel/Boykin_spaniel_02445.jpg
# Img: dogImages/train/101.Maltese/Maltese_06768.jpg
# Img: dogImages/train/068.Flat-coated_retriever/Flat-coated_retriever_04709.jpg
# Img: dogImages/train/115.Papillon/Papillon_07505.jpg
# Img: dogImages/train/005.Alaskan_malamute/Alaskan_malamute_00320.jpg
# Img: dogImages/train/066.Field_spaniel/Field_spaniel_04601.jpg
# Img: dogImages/train/026.Black_russian_terrier/Black_russian_terrier_01843.jpg
# Img: dogImages/train/111.Norwich_terrier/Norwich_terrier_07246.jpg
# Img: dogImages/train/123.Pomeranian/Pomeranian_07893.jpg
# Img: dogImages/train/029.Border_collie/Border_collie_02013.jpg
# Img: dogImages/train/102.Manchester_terrier/Manchester_terrier_06785.jpg
# Img: dogImages/train/010.Anatolian_shepherd_dog/Anatolian_shepherd_dog_00703.jpg
# Img: dogImages/train/115.Papillon/Papillon_07471.jpg
# Img: dogImages/train/082.Havanese/Havanese_05594.jpg
# Img: dogImages/train/052.Clumber_spaniel/Clumber_spaniel_03699.jpg
# Img: dogImages/train/048.Chihuahua/Chihuahua_03458.jpg
# Img: dogImages/train/058.Dandie_dinmont_terrier/Dandie_dinmont_terrier_04123.jpg
# Img: dogImages/train/030.Border_terrier/Border_terrier_02108.jpg
# Img: dogImages/train/020.Belgian_malinois/Belgian_malinois_01461.jpg
# Img: dogImages/train/071.German_shepherd_dog/German_shepherd_dog_04901.jpg
# Img: dogImages/train/118.Pembroke_welsh_corgi/Pembroke_welsh_corgi_07651.jpg
# Img: dogImages/train/021.Belgian_sheepdog/Belgian_sheepdog_01509.jpg
# Img: dogImages/train/094.Komondor/Komondor_06336.jpg
# Img: dogImages/train/098.Leonberger/Leonberger_06565.jpg
# Img: dogImages/train/118.Pembroke_welsh_corgi/Pembroke_welsh_corgi_07666.jpg
# Img: dogImages/train/132.Xoloitzcuintli/Xoloitzcuintli_08303.jpg
# Img: dogImages/train/019.Bedlington_terrier/Bedlington_terrier_01342.jpg
# Img: dogImages/train/090.Italian_greyhound/Italian_greyhound_06092.jpg
# Img: dogImages/train/081.Greyhound/Greyhound_05525.jpg
# Img: dogImages/train/040.Bulldog/Bulldog_02816.jpg
# Img: dogImages/train/076.Golden_retriever/Golden_retriever_05225.jpg
# Img: dogImages/train/047.Chesapeake_bay_retriever/Chesapeake_bay_retriever_03350.jpg
# Img: dogImages/train/052.Clumber_spaniel/Clumber_spaniel_03696.jpg
# Img: dogImages/train/028.Bluetick_coonhound/Bluetick_coonhound_01988.jpg
# Img: dogImages/train/046.Cavalier_king_charles_spaniel/Cavalier_king_charles_spaniel_03325.jpg
# Img: dogImages/train/043.Canaan_dog/Canaan_dog_03057.jpg
# Img: dogImages/train/116.Parson_russell_terrier/Parson_russell_terrier_07521.jpg
# Img: dogImages/train/076.Golden_retriever/Golden_retriever_05233.jpg
# Img: dogImages/train/008.American_staffordshire_terrier/American_staffordshire_terrier_00542.jpg
# Img: dogImages/train/056.Dachshund/Dachshund_03989.jpg
# Img: dogImages/train/071.German_shepherd_dog/German_shepherd_dog_04930.jpg
# Img: dogImages/train/127.Silky_terrier/Silky_terrier_08045.jpg
# Img: dogImages/train/037.Brittany/Brittany_02631.jpg
# Img: dogImages/train/072.German_shorthaired_pointer/German_shorthaired_pointer_05017.jpg
# Img: dogImages/train/074.Giant_schnauzer/Giant_schnauzer_05091.jpg
# Img: dogImages/train/102.Manchester_terrier/Manchester_terrier_06803.jpg
# Img: dogImages/train/080.Greater_swiss_mountain_dog/Greater_swiss_mountain_dog_05444.jpg
# Img: dogImages/train/092.Keeshond/Keeshond_06232.jpg
# Img: dogImages/train/105.Neapolitan_mastiff/Neapolitan_mastiff_06955.jpg
# Img: dogImages/train/055.Curly-coated_retriever/Curly-coated_retriever_03899.jpg
# Img: dogImages/train/029.Border_collie/Border_collie_02057.jpg
# Img: dogImages/train/082.Havanese/Havanese_05609.jpg
# Img: dogImages/train/128.Smooth_fox_terrier/Smooth_fox_terrier_08098.jpg
# Img: dogImages/train/080.Greater_swiss_mountain_dog/Greater_swiss_mountain_dog_05466.jpg
# Img: dogImages/train/014.Basenji/Basenji_00947.jpg
# Img: dogImages/train/063.English_springer_spaniel/English_springer_spaniel_04456.jpg
# Img: dogImages/train/064.English_toy_spaniel/English_toy_spaniel_04531.jpg
# Img: dogImages/train/116.Parson_russell_terrier/Parson_russell_terrier_07526.jpg
# Img: dogImages/train/035.Boykin_spaniel/Boykin_spaniel_02447.jpg
# Img: dogImages/train/132.Xoloitzcuintli/Xoloitzcuintli_08288.jpg
# Img: dogImages/train/039.Bull_terrier/Bull_terrier_02721.jpg
# Img: dogImages/train/014.Basenji/Basenji_01008.jpg
# Img: dogImages/train/119.Petit_basset_griffon_vendeen/Petit_basset_griffon_vendeen_07718.jpg
# Img: dogImages/train/021.Belgian_sheepdog/Belgian_sheepdog_01513.jpg
# Img: dogImages/train/051.Chow_chow/Chow_chow_03665.jpg
# Img: dogImages/train/062.English_setter/English_setter_04418.jpg
# Img: dogImages/train/048.Chihuahua/Chihuahua_03406.jpg
# Img: dogImages/train/003.Airedale_terrier/Airedale_terrier_00191.jpg
# Img: dogImages/train/040.Bulldog/Bulldog_02867.jpg
# Img: dogImages/train/013.Australian_terrier/Australian_terrier_00894.jpg
# Img: dogImages/train/010.Anatolian_shepherd_dog/Anatolian_shepherd_dog_00683.jpg
# Img: dogImages/train/087.Irish_terrier/Irish_terrier_05925.jpg
# Img: dogImages/train/048.Chihuahua/Chihuahua_03433.jpg
# Img: dogImages/train/059.Doberman_pinscher/Doberman_pinscher_04175.jpg
# Img: dogImages/train/007.American_foxhound/American_foxhound_00530.jpg
# Img: dogImages/train/057.Dalmatian/Dalmatian_04028.jpg
# Img: dogImages/train/012.Australian_shepherd/Australian_shepherd_00824.jpg
# Img: dogImages/train/014.Basenji/Basenji_01003.jpg
# Img: dogImages/train/013.Australian_terrier/Australian_terrier_00946.jpg
# Img: dogImages/train/036.Briard/Briard_02511.jpg
# Img: dogImages/train/002.Afghan_hound/Afghan_hound_00122.jpg
# Img: dogImages/train/044.Cane_corso/Cane_corso_03123.jpg
# Img: dogImages/train/033.Bouvier_des_flandres/Bouvier_des_flandres_02341.jpg
# Img: dogImages/train/036.Briard/Briard_02563.jpg
# Img: dogImages/train/089.Irish_wolfhound/Irish_wolfhound_06068.jpg
# Img: dogImages/train/094.Komondor/Komondor_06341.jpg
# Img: dogImages/train/038.Brussels_griffon/Brussels_griffon_02705.jpg
# Img: dogImages/train/116.Parson_russell_terrier/Parson_russell_terrier_07545.jpg
# Img: dogImages/train/121.Plott/Plott_07773.jpg
# Img: dogImages/train/051.Chow_chow/Chow_chow_03618.jpg
# Img: dogImages/train/010.Anatolian_shepherd_dog/Anatolian_shepherd_dog_00675.jpg
# Img: dogImages/train/030.Border_terrier/Border_terrier_02128.jpg
# Img: dogImages/train/051.Chow_chow/Chow_chow_03622.jpg
# Img: dogImages/train/039.Bull_terrier/Bull_terrier_02778.jpg
# Img: dogImages/train/038.Brussels_griffon/Brussels_griffon_02669.jpg
# Img: dogImages/train/046.Cavalier_king_charles_spaniel/Cavalier_king_charles_spaniel_03249.jpg
# Img: dogImages/train/012.Australian_shepherd/Australian_shepherd_00883.jpg
# Img: dogImages/train/127.Silky_terrier/Silky_terrier_08073.jpg
# Img: dogImages/train/061.English_cocker_spaniel/English_cocker_spaniel_04339.jpg
# Img: dogImages/train/114.Otterhound/Otterhound_07408.jpg
# Img: dogImages/train/112.Nova_scotia_duck_tolling_retriever/Nova_scotia_duck_tolling_retriever_07344.jpg
# Img: dogImages/train/080.Greater_swiss_mountain_dog/Greater_swiss_mountain_dog_05471.jpg
# Img: dogImages/train/018.Beauceron/Beauceron_01294.jpg
# Img: dogImages/train/112.Nova_scotia_duck_tolling_retriever/Nova_scotia_duck_tolling_retriever_07286.jpg
# Img: dogImages/train/089.Irish_wolfhound/Irish_wolfhound_06077.jpg
# Img: dogImages/train/091.Japanese_chin/Japanese_chin_06170.jpg
# Img: dogImages/train/057.Dalmatian/Dalmatian_04084.jpg
# Img: dogImages/train/029.Border_collie/Border_collie_02069.jpg
# Img: dogImages/train/046.Cavalier_king_charles_spaniel/Cavalier_king_charles_spaniel_03261.jpg
# Img: dogImages/train/048.Chihuahua/Chihuahua_03416.jpg

# %% [markdown]
# ---
# <a id='step2'></a>
# ## Step 2: Detect Dogs
#
# In this section, we use a pre-trained [ResNet-50](http://ethereon.github.io/netscope/#/gist/db945b393d40bfa26006) model to detect dogs in images.  Our first line of code downloads the ResNet-50 model, along with weights that have been trained on [ImageNet](http://www.image-net.org/), a very large, very popular dataset used for image classification and other vision tasks.  ImageNet contains over 10 million URLs, each linking to an image containing an object from one of [1000 categories](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a).  Given an image, this pre-trained ResNet-50 model returns a prediction (derived from the available categories in ImageNet) for the object that is contained in the image.

# %%
from keras.applications.resnet50 import ResNet50

# define ResNet50 model
ResNet50_model = ResNet50(weights='imagenet')

# %% [markdown]
# ### Pre-process the Data
#
# When using TensorFlow as backend, Keras CNNs require a 4D array (which we'll also refer to as a 4D tensor) as input, with shape
#
# $$
# (\text{nb_samples}, \text{rows}, \text{columns}, \text{channels}),
# $$
#
# where `nb_samples` corresponds to the total number of images (or samples), and `rows`, `columns`, and `channels` correspond to the number of rows, columns, and channels for each image, respectively.
#
# The `path_to_tensor` function below takes a string-valued file path to a color image as input and returns a 4D tensor suitable for supplying to a Keras CNN.  The function first loads the image and resizes it to a square image that is $224 \times 224$ pixels.  Next, the image is converted to an array, which is then resized to a 4D tensor.  In this case, since we are working with color images, each image has three channels.  Likewise, since we are processing a single image (or sample), the returned tensor will always have shape
#
# $$
# (1, 224, 224, 3).
# $$
#
# The `paths_to_tensor` function takes a numpy array of string-valued image paths as input and returns a 4D tensor with shape
#
# $$
# (\text{nb_samples}, 224, 224, 3).
# $$
#
# Here, `nb_samples` is the number of samples, or number of images, in the supplied array of image paths.  It is best to think of `nb_samples` as the number of 3D tensors (where each 3D tensor corresponds to a different image) in your dataset!

# %%
from keras.preprocessing import image                  
from tqdm import tqdm

def path_to_tensor(img_path):
    # loads RGB image as PIL.Image.Image type
    img = image.load_img(img_path, target_size=(224, 224))
    # convert PIL.Image.Image type to 3D tensor with shape (224, 224, 3)
    x = image.img_to_array(img)
    # convert 3D tensor to 4D tensor with shape (1, 224, 224, 3) and return 4D tensor
    return np.expand_dims(x, axis=0)

def paths_to_tensor(img_paths):
    list_of_tensors = [path_to_tensor(img_path) for img_path in tqdm(img_paths)]
    return np.vstack(list_of_tensors)

# %% [markdown]
# ### Making Predictions with ResNet-50
#
# Getting the 4D tensor ready for ResNet-50, and for any other pre-trained model in Keras, requires some additional processing.  First, the RGB image is converted to BGR by reordering the channels.  All pre-trained models have the additional normalization step that the mean pixel (expressed in RGB as $[103.939, 116.779, 123.68]$ and calculated from all pixels in all images in ImageNet) must be subtracted from every pixel in each image.  This is implemented in the imported function `preprocess_input`.  If you're curious, you can check the code for `preprocess_input` [here](https://github.com/fchollet/keras/blob/master/keras/applications/imagenet_utils.py).
#
# Now that we have a way to format our image for supplying to ResNet-50, we are now ready to use the model to extract the predictions.  This is accomplished with the `predict` method, which returns an array whose $i$-th entry is the model's predicted probability that the image belongs to the $i$-th ImageNet category.  This is implemented in the `ResNet50_predict_labels` function below.
#
# By taking the argmax of the predicted probability vector, we obtain an integer corresponding to the model's predicted object class, which we can identify with an object category through the use of this [dictionary](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a).

# %%
from keras.applications.resnet50 import preprocess_input, decode_predictions

def ResNet50_predict_labels(img_path):
    # returns prediction vector for image located at img_path
    img = preprocess_input(path_to_tensor(img_path))
    return np.argmax(ResNet50_model.predict(img))

# %% [markdown]
# ### Write a Dog Detector
#
# While looking at the [dictionary](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a), you will notice that the categories corresponding to dogs appear in an uninterrupted sequence and correspond to dictionary keys 151-268, inclusive, to include all categories from `'Chihuahua'` to `'Mexican hairless'`.  Thus, in order to check to see if an image is predicted to contain a dog by the pre-trained ResNet-50 model, we need only check if the `ResNet50_predict_labels` function above returns a value between 151 and 268 (inclusive).
#
# We use these ideas to complete the `dog_detector` function below, which returns `True` if a dog is detected in an image (and `False` if not).

# %%
### returns "True" if a dog is detected in the image stored at img_path
def dog_detector(img_path):
    prediction = ResNet50_predict_labels(img_path)
    return ((prediction <= 268) & (prediction >= 151))

# %% [markdown]
# ### (IMPLEMENTATION) Assess the Dog Detector
#
# __Question 3:__ Use the code cell below to test the performance of your `dog_detector` function.
# - What percentage of the images in `human_files_short` have a detected dog?
# - What percentage of the images in `dog_files_short` have a detected dog?
#
# __Answer:__

# %%
### TODO: Test the performance of the dog_detector function
### on the images in human_files_short and dog_files_short.

### What percentage of the images in human_files_short have a detected dog?
def checkPerformance(file, detector):
    result = 0
    for x in file:
        if detector(x):
            result += 1
    return 100.*result/len(file)
print (checkPerformance(human_files_short, dog_detector), 'percentage of the images in human_files_short are detected dog')
print (checkPerformance(dog_files_short, dog_detector), 'percentage of the images in dog_files_short are detected dog')
# Out:
# (2.0, 'percentage of the images in human_files_short are detected dog')
# (100.0, 'percentage of the images in dog_files_short are detected dog')

# %% [markdown]
# ---
# <a id='step3'></a>
# ## Step 3: Create a CNN to Classify Dog Breeds (from Scratch)
#
# Now that we have functions for detecting humans and dogs in images, we need a way to predict breed from images.  In this step, you will create a CNN that classifies dog breeds.  You must create your CNN _from scratch_ (so, you can't use transfer learning _yet_!), and you must attain a test accuracy of at least 1%.  In Step 5 of this notebook, you will have the opportunity to use transfer learning to create a CNN that attains greatly improved accuracy.
#
# Be careful with adding too many trainable layers!  More parameters means longer training, which means you are more likely to need a GPU to accelerate the training process.  Thankfully, Keras provides a handy estimate of the time that each epoch is likely to take; you can extrapolate this estimate to figure out how long it will take for your algorithm to train.
#
# We mention that the task of assigning breed to dogs from images is considered exceptionally challenging.  To see why, consider that *even a human* would have great difficulty in distinguishing between a Brittany and a Welsh Springer Spaniel.
#
# Brittany | Welsh Springer Spaniel
# - | -
# <img src="images/Brittany_02625.jpg" width="100"> | <img src="images/Welsh_springer_spaniel_08203.jpg" width="200">
#
# It is not difficult to find other dog breed pairs with minimal inter-class variation (for instance, Curly-Coated Retrievers and American Water Spaniels).
#
# Curly-Coated Retriever | American Water Spaniel
# - | -
# <img src="images/Curly-coated_retriever_03896.jpg" width="200"> | <img src="images/American_water_spaniel_00648.jpg" width="200">
#
#
# Likewise, recall that labradors come in yellow, chocolate, and black.  Your vision-based algorithm will have to conquer this high intra-class variation to determine how to classify all of these different shades as the same breed.
#
# Yellow Labrador | Chocolate Labrador | Black Labrador
# - | -
# <img src="images/Labrador_retriever_06457.jpg" width="150"> | <img src="images/Labrador_retriever_06455.jpg" width="240"> | <img src="images/Labrador_retriever_06449.jpg" width="220">
#
# We also mention that random chance presents an exceptionally low bar: setting aside the fact that the classes are slightly imabalanced, a random guess will provide a correct answer roughly 1 in 133 times, which corresponds to an accuracy of less than 1%.
#
# Remember that the practice is far ahead of the theory in deep learning.  Experiment with many different architectures, and trust your intuition.  And, of course, have fun!
#
# ### Pre-process the Data
#
# We rescale the images by dividing every pixel in every image by 255.

# %%
from PIL import ImageFile                            
ImageFile.LOAD_TRUNCATED_IMAGES = True                 

# pre-process the data for Keras
train_tensors = paths_to_tensor(train_files).astype('float32')/255
valid_tensors = paths_to_tensor(valid_files).astype('float32')/255
test_tensors = paths_to_tensor(test_files).astype('float32')/255
# Out:
# 100%|██████████| 6680/6680 [01:05<00:00, 101.35it/s]
# 100%|██████████| 835/835 [00:08<00:00, 104.33it/s]
# 100%|██████████| 836/836 [00:07<00:00, 113.42it/s]

# %% [markdown]
# ### (IMPLEMENTATION) Model Architecture
#
# Create a CNN to classify dog breed.  At the end of your code cell block, summarize the layers of your model by executing the line:
#
#         model.summary()
#
# We have imported some Python modules to get you started, but feel free to import as many modules as you need.  If you end up getting stuck, here's a hint that specifies a model that trains relatively fast on CPU and attains >1% test accuracy in 5 epochs:
#
# ![Sample CNN](images/sample_cnn.png)
#
# __Question 4:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.  If you chose to use the hinted architecture above, describe why you think that CNN architecture should work well for the image classification task.
#
# __Answer:__
#
# The CNN architecture works well for the image classification task because its convolution layers can detect regional patterns in the images and the pooling layers can reduce dimensionality of an array. The dropout layers can also prevent overfitting, and the relu functions were used to deal with the vanishing gradient problem. The softmax function is the best to aquire probability for each output node.

# %%
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.layers import Dropout, Flatten, Dense
from keras.models import Sequential

model = Sequential()

### TODO: Define your architecture.
model.add(Conv2D(16, (2, 2), activation='relu', padding = 'same', input_shape=(224, 224, 3)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(32, (2, 2), activation='relu', padding = 'same'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, (2, 2), activation='relu', padding = 'same'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.4))
model.add(Flatten())
model.add(Dense(500, activation = 'relu'))
model.add(Dropout(0.2))
model.add(Dense(133, activation = 'softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 224, 224, 16)      208
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 112, 112, 16)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 112, 112, 32)      2080
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 56, 56, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 56, 56, 64)        8256
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 28, 28, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 28, 28, 64)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 50176)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 500)               25088500
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 133)               66633
# =================================================================
# Total params: 25,165,677
# Trainable params: 25,165,677
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Compile the Model

# %%
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### (IMPLEMENTATION) Train the Model
#
# Train your model in the code cell below.  Use model checkpointing to save the model that attains the best validation loss.
#
# You are welcome to [augment the training data](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html), but this is not a requirement.

# %%
from keras.callbacks import ModelCheckpoint  

### TODO: specify the number of epochs that you would like to use to train the model.

epochs = 5

### Do NOT modify the code below this line.

checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.from_scratch.hdf5', 
                               verbose=1, save_best_only=True)

model.fit(train_tensors, train_targets, 
          validation_data=(valid_tensors, valid_targets),
          epochs=epochs, batch_size=20, callbacks=[checkpointer], verbose=1)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/5
# 6660/6680 [============================>.] - ETA: 0s - loss: 4.9285 - acc: 0.0198
# Epoch 00001: val_loss improved from inf to 4.59178, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 335s 50ms/step - loss: 4.9281 - acc: 0.0198 - val_loss: 4.5918 - val_acc: 0.0419
# Epoch 2/5
# 6660/6680 [============================>.] - ETA: 1s - loss: 4.3574 - acc: 0.0592
# Epoch 00002: val_loss improved from 4.59178 to 4.33668, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 365s 55ms/step - loss: 4.3572 - acc: 0.0593 - val_loss: 4.3367 - val_acc: 0.0599
# Epoch 3/5
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.6188 - acc: 0.1782
# Epoch 00003: val_loss did not improve
# 6680/6680 [==============================] - 332s 50ms/step - loss: 3.6162 - acc: 0.1784 - val_loss: 4.4048 - val_acc: 0.0826
# Epoch 4/5
# 6660/6680 [============================>.] - ETA: 1s - loss: 2.2482 - acc: 0.4526
# Epoch 00004: val_loss did not improve
# 6680/6680 [==============================] - 347s 52ms/step - loss: 2.2461 - acc: 0.4531 - val_loss: 4.6891 - val_acc: 0.0886
# Epoch 5/5
# 6660/6680 [============================>.] - ETA: 1s - loss: 1.0122 - acc: 0.7426
# Epoch 00005: val_loss did not improve
# 6680/6680 [==============================] - 370s 55ms/step - loss: 1.0137 - acc: 0.7424 - val_loss: 6.0334 - val_acc: 0.0743

# %% [markdown]
# ### Load the Model with the Best Validation Loss

# %%
model.load_weights('saved_models/weights.best.from_scratch.hdf5')

# %% [markdown]
# ### Test the Model
#
# Try out your model on the test dataset of dog images.  Ensure that your test accuracy is greater than 1%.

# %%
# get index of predicted dog breed for each image in test set
dog_breed_predictions = [np.argmax(model.predict(np.expand_dims(tensor, axis=0))) for tensor in test_tensors]

# report test accuracy
test_accuracy = 100*np.sum(np.array(dog_breed_predictions)==np.argmax(test_targets, axis=1))/len(dog_breed_predictions)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 4.0000%

# %% [markdown]
# ---
# <a id='step4'></a>
# ## Step 4: Use a CNN to Classify Dog Breeds
#
# To reduce training time without sacrificing accuracy, we show you how to train a CNN using transfer learning.  In the following step, you will get a chance to use transfer learning to train your own CNN.
#
# ### Obtain Bottleneck Features

# %%
bottleneck_features = np.load('bottleneck_features/DogVGG16Data.npz')
train_VGG16 = bottleneck_features['train']
valid_VGG16 = bottleneck_features['valid']
test_VGG16 = bottleneck_features['test']

# %% [markdown]
# ### Model Architecture
#
# The model uses the the pre-trained VGG-16 model as a fixed feature extractor, where the last convolutional output of VGG-16 is fed as input to our model.  We only add a global average pooling layer and a fully connected layer, where the latter contains one node for each dog category and is equipped with a softmax.

# %%
VGG16_model = Sequential()
VGG16_model.add(GlobalAveragePooling2D(input_shape=train_VGG16.shape[1:]))
VGG16_model.add(Dense(133, activation='softmax'))

VGG16_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# global_average_pooling2d_1 ( (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 133)               68229
# =================================================================
# Total params: 68,229
# Trainable params: 68,229
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Compile the Model

# %%
VGG16_model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# %% [markdown]
# ### Train the Model

# %%
checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.VGG16.hdf5', 
                               verbose=1, save_best_only=True)

VGG16_model.fit(train_VGG16, train_targets, 
          validation_data=(valid_VGG16, valid_targets),
          epochs=20, batch_size=20, callbacks=[checkpointer], verbose=1)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/20
# 6520/6680 [============================>.] - ETA: 0s - loss: 11.8298 - acc: 0.1282
# Epoch 00001: val_loss improved from inf to 10.02919, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 284us/step - loss: 11.7862 - acc: 0.1301 - val_loss: 10.0292 - val_acc: 0.2251
# Epoch 2/20
# 6540/6680 [============================>.] - ETA: 0s - loss: 9.1125 - acc: 0.3121
# Epoch 00002: val_loss improved from 10.02919 to 8.99599, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s 152us/step - loss: 9.1146 - acc: 0.3132 - val_loss: 8.9960 - val_acc: 0.3353
# Epoch 3/20
# 6580/6680 [============================>.] - ETA: 0s - loss: 8.3266 - acc: 0.4014
# Epoch 00003: val_loss improved from 8.99599 to 8.58196, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s 201us/step - loss: 8.3199 - acc: 0.4018 - val_loss: 8.5820 - val_acc: 0.3677
# Epoch 4/20
# 6560/6680 [============================>.] - ETA: 0s - loss: 7.9678 - acc: 0.4453
# Epoch 00004: val_loss improved from 8.58196 to 8.35646, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s 199us/step - loss: 7.9787 - acc: 0.4439 - val_loss: 8.3565 - val_acc: 0.3820
# Epoch 5/20
# 6320/6680 [===========================>..] - ETA: 0s - loss: 7.5962 - acc: 0.4729
# Epoch 00005: val_loss improved from 8.35646 to 7.98939, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s 186us/step - loss: 7.5761 - acc: 0.4759 - val_loss: 7.9894 - val_acc: 0.4000
# Epoch 6/20
# 6500/6680 [============================>.] - ETA: 0s - loss: 7.2554 - acc: 0.5092
# Epoch 00006: val_loss improved from 7.98939 to 7.85024, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s 224us/step - loss: 7.2680 - acc: 0.5090 - val_loss: 7.8502 - val_acc: 0.4263
# Epoch 7/20
# 6600/6680 [============================>.] - ETA: 0s - loss: 6.9821 - acc: 0.5248
# Epoch 00007: val_loss improved from 7.85024 to 7.59226, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s 192us/step - loss: 6.9912 - acc: 0.5246 - val_loss: 7.5923 - val_acc: 0.4275
# Epoch 8/20
# 6520/6680 [============================>.] - ETA: 0s - loss: 6.7039 - acc: 0.5480
# Epoch 00008: val_loss improved from 7.59226 to 7.39818, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s 177us/step - loss: 6.7055 - acc: 0.5479 - val_loss: 7.3982 - val_acc: 0.4491
# Epoch 9/20
# 6660/6680 [============================>.] - ETA: 0s - loss: 6.5607 - acc: 0.5641
# Epoch 00009: val_loss did not improve
# 6680/6680 [==============================] - 1s 159us/step - loss: 6.5582 - acc: 0.5641 - val_loss: 7.4375 - val_acc: 0.4287
# Epoch 10/20
# 6540/6680 [============================>.] - ETA: 0s - loss: 6.4300 - acc: 0.5775
# Epoch 00010: val_loss improved from 7.39818 to 7.30105, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s 160us/step - loss: 6.4486 - acc: 0.5765 - val_loss: 7.3011 - val_acc: 0.4347
# Epoch 11/20
# 6560/6680 [============================>.] - ETA: 0s - loss: 6.2462 - acc: 0.5867
# Epoch 00011: val_loss improved from 7.30105 to 7.03945, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s 151us/step - loss: 6.2432 - acc: 0.5865 - val_loss: 7.0395 - val_acc: 0.4707
# Epoch 12/20
# 6320/6680 [===========================>..] - ETA: 0s - loss: 5.9898 - acc: 0.6070
# Epoch 00012: val_loss improved from 7.03945 to 6.75498, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s 148us/step - loss: 5.9696 - acc: 0.6085 - val_loss: 6.7550 - val_acc: 0.4898
# Epoch 13/20
# 6500/6680 [============================>.] - ETA: 0s - loss: 5.8446 - acc: 0.6248
# Epoch 00013: val_loss did not improve
# 6680/6680 [==============================] - 1s 143us/step - loss: 5.8475 - acc: 0.6246 - val_loss: 6.8289 - val_acc: 0.4898
# Epoch 14/20
# 6380/6680 [===========================>..] - ETA: 0s - loss: 5.8081 - acc: 0.6276
# Epoch 00014: val_loss did not improve
# 6680/6680 [==============================] - 1s 155us/step - loss: 5.8141 - acc: 0.6259 - val_loss: 6.7986 - val_acc: 0.4898
# Epoch 15/20
# 6400/6680 [===========================>..] - ETA: 0s - loss: 5.7066 - acc: 0.6347
# Epoch 00015: val_loss improved from 6.75498 to 6.57107, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s 147us/step - loss: 5.7290 - acc: 0.6334 - val_loss: 6.5711 - val_acc: 0.5018
# Epoch 16/20
# 6560/6680 [============================>.] - ETA: 0s - loss: 5.6300 - acc: 0.6409
# Epoch 00016: val_loss improved from 6.57107 to 6.43199, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s 160us/step - loss: 5.6238 - acc: 0.6412 - val_loss: 6.4320 - val_acc: 0.5066
# Epoch 17/20
# 6460/6680 [============================>.] - ETA: 0s - loss: 5.5138 - acc: 0.6478
# Epoch 00017: val_loss did not improve
# 6680/6680 [==============================] - 1s 159us/step - loss: 5.5225 - acc: 0.6470 - val_loss: 6.4872 - val_acc: 0.5102
# Epoch 18/20
# 6640/6680 [============================>.] - ETA: 0s - loss: 5.4597 - acc: 0.6538
# Epoch 00018: val_loss did not improve
# 6680/6680 [==============================] - 1s 173us/step - loss: 5.4633 - acc: 0.6536 - val_loss: 6.4331 - val_acc: 0.5126
# Epoch 19/20
# 6660/6680 [============================>.] - ETA: 0s - loss: 5.4522 - acc: 0.6553
# Epoch 00019: val_loss improved from 6.43199 to 6.39531, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s 184us/step - loss: 5.4480 - acc: 0.6555 - val_loss: 6.3953 - val_acc: 0.5150
# Epoch 20/20
# 6640/6680 [============================>.] - ETA: 0s - loss: 5.4484 - acc: 0.6571
# Epoch 00020: val_loss did not improve
# 6680/6680 [==============================] - 1s 201us/step - loss: 5.4395 - acc: 0.6575 - val_loss: 6.4323 - val_acc: 0.5150

# %% [markdown]
# ### Load the Model with the Best Validation Loss

# %%
VGG16_model.load_weights('saved_models/weights.best.VGG16.hdf5')

# %% [markdown]
# ### Test the Model
#
# Now, we can use the CNN to test how well it identifies breed within our test dataset of dog images.  We print the test accuracy below.

# %%
# get index of predicted dog breed for each image in test set
VGG16_predictions = [np.argmax(VGG16_model.predict(np.expand_dims(feature, axis=0))) for feature in test_VGG16]

# report test accuracy
test_accuracy = 100*np.sum(np.array(VGG16_predictions)==np.argmax(test_targets, axis=1))/len(VGG16_predictions)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 53.0000%

# %% [markdown]
# ### Predict Dog Breed with the Model

# %%
from extract_bottleneck_features import *

def VGG16_predict_breed(img_path):
    # extract bottleneck features
    bottleneck_feature = extract_VGG16(path_to_tensor(img_path))
    # obtain predicted vector
    predicted_vector = VGG16_model.predict(bottleneck_feature)
    # return dog breed that is predicted by the model
    return dog_names[np.argmax(predicted_vector)]

# %% [markdown]
# ---
# <a id='step5'></a>
# ## Step 5: Create a CNN to Classify Dog Breeds (using Transfer Learning)
#
# You will now use transfer learning to create a CNN that can identify dog breed from images.  Your CNN must attain at least 60% accuracy on the test set.
#
# In Step 4, we used transfer learning to create a CNN using VGG-16 bottleneck features.  In this section, you must use the bottleneck features from a different pre-trained model.  To make things easier for you, we have pre-computed the features for all of the networks that are currently available in Keras:
# - [VGG-19](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogVGG19Data.npz) bottleneck features
# - [ResNet-50](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogResnet50Data.npz) bottleneck features
# - [Inception](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogInceptionV3Data.npz) bottleneck features
# - [Xception](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogXceptionData.npz) bottleneck features
#
# The files are encoded as such:
#
#     Dog{network}Data.npz
#
# where `{network}`, in the above filename, can be one of `VGG19`, `Resnet50`, `InceptionV3`, or `Xception`.  Pick one of the above architectures, download the corresponding bottleneck features, and store the downloaded file in the `bottleneck_features/` folder in the repository.
#
# ### (IMPLEMENTATION) Obtain Bottleneck Features
#
# In the code block below, extract the bottleneck features corresponding to the train, test, and validation sets by running the following:
#
#     bottleneck_features = np.load('bottleneck_features/Dog{network}Data.npz')
#     train_{network} = bottleneck_features['train']
#     valid_{network} = bottleneck_features['valid']
#     test_{network} = bottleneck_features['test']

# %%
### TODO: Obtain bottleneck features from another pre-trained CNN.
# bottleneck_features = np.load('bottleneck_features/DogVGG19Data.npz')
# train_VGG19 = bottleneck_features['train']
# valid_VGG19 = bottleneck_features['valid']
# test_VGG19 = bottleneck_features['test']

# bottleneck_features = np.load('bottleneck_features/DogVGG19Data.npz')
# train_ResNet50 = bottleneck_features['train']
# valid_ResNet50 = bottleneck_features['valid']
# test_ResNet50 = bottleneck_features['test']

bottleneck_features = np.load('bottleneck_features/DogInceptionV3Data.npz')
train_InceptionV3 = bottleneck_features['train']
valid_InceptionV3 = bottleneck_features['valid']
test_InceptionV3 = bottleneck_features['test']

# %% [markdown]
# ### (IMPLEMENTATION) Model Architecture
#
# Create a CNN to classify dog breed.  At the end of your code cell block, summarize the layers of your model by executing the line:
#
#         <your model's name>.summary()
#
# __Question 5:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.  Describe why you think the architecture is suitable for the current problem.
#
# __Answer:__
#
# Inception-v3 is trained for the ImageNet Large Visual Recognition Challenge using the data from 2012. This is a standard task in computer vision, where models try to classify entire images into 1000 classes, like "Zebra", "Dalmatian", and "Dishwasher".
# InceptionV3 is a variant of the GoogleNet with factorization (factorize convolutions into smaller convolutions) and Batch Normalization auxiliary (fully connected layer of auxiliary classifier is also-normalized). The architure wasn't very complicated since we were using transfer learning.
#
# References:
# https://www.packtpub.com/mapt/book/big_data_and_business_intelligence/9781786466587/8/ch08lvl1sec48/inception-v3
#
# https://codelabs.developers.google.com/codelabs/cpb102-txf-learning/index.html?index=..%2F..%2Findex#0
#
# https://www.kaggle.com/google-brain/inception-v3

# %%
### TODO: Define your architecture.
# import os
# from keras.preprocessing.image import ImageDataGenerator
# from keras.models import Sequential
# from keras.layers import Dense, Dropout, Activation, Flatten
# from keras.layers import Conv2D, MaxPooling2D

# from keras.layers import Flatten,Dense, Input
# from keras.preprocessing import image
# from keras.models import Model
# from keras.preprocessing.image import ImageDataGenerator

# # ResNet50_model = ResNet50(include_top=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000)
# # #ResNet50(include_top=False, weights='imagenet', input_tensor=Input(shape=(224,224,3)))

# # top_model = Sequential()
# # top_model.add(Flatten(input_shape=ResNet50_model.output_shape[1:]))
# # top_model.add(Dense(256, activation='relu'))
# # top_model.add(Dropout(0.5))
# # top_model.add(Dense(1, activation='sigmoid'))
# # # top_model.load_weights(top_model_weights_path)

# # ResNet50_model = Model(input=ResNet50_model.input, output=top_model(model.output))
# # # ResNet50_model = Sequential()
# # # ResNet50_model.add(Flatten(input_shape=(7,7,512)))
# # # ResNet50_model.add(GlobalAveragePooling2D(input_shape=(5, 5, 2048)))
# # # ResNet50_model.add(Dense(133, activation='softmax'))

# # ResNet50_model.summary()
# VGG19_model = Sequential()
# VGG19_model.add(GlobalAveragePooling2D(input_shape=(5, 5, 2048)))
# VGG19_model.add(Dense(133, activation='softmax'))
# VGG19_model.summary()
from keras.layers import Dense, Flatten
from keras.models import Sequential

InceptionV3_model = Sequential()
InceptionV3_model.add(GlobalAveragePooling2D(input_shape=(5, 5, 2048)))
InceptionV3_model.add(Dense(133, activation='softmax'))
InceptionV3_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# global_average_pooling2d_2 ( (None, 2048)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 133)               272517
# =================================================================
# Total params: 272,517
# Trainable params: 272,517
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### (IMPLEMENTATION) Compile the Model

# %%
### TODO: Compile the model.
# from keras.optimizers import SGD
# sgd = SGD(lr=0.1, decay=1e-6, momentum=0.9, nesterov=True)
# VGG19_model.compile(loss='categorical_crossentropy', optimizer='rmsprop',metrics=['accuracy'])

InceptionV3_model.compile(loss='categorical_crossentropy', optimizer='rmsprop',
                  metrics=['accuracy'])

# %% [markdown]
# ### (IMPLEMENTATION) Train the Model
#
# Train your model in the code cell below.  Use model checkpointing to save the model that attains the best validation loss.
#
# You are welcome to [augment the training data](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html), but this is not a requirement.

# %%
### TODO: Train the model.
from keras.callbacks import ModelCheckpoint
# ResNet50_model
# print(train_VGG19.shape)
# print(valid_VGG19.shape)
# print(test_VGG19.shape)
# checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.VGG19.hdf5', 
#                                verbose=1, save_best_only=True)

# VGG19_model.fit(train_VGG19, train_targets, epochs=20, validation_data=(valid_VGG19, valid_targets),
#           callbacks=[checkpointer], verbose=1, shuffle=True)
checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.InceptionV3.hdf5', verbose=1,
                               save_best_only=True)
InceptionV3_model.fit(train_InceptionV3, train_targets, epochs=20, validation_data=(valid_InceptionV3, valid_targets),
          callbacks=[checkpointer], verbose=1, shuffle=True)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/20
# 6496/6680 [============================>.] - ETA: 0s - loss: 1.2136 - acc: 0.6980
# Epoch 00001: val_loss improved from inf to 0.70868, saving model to saved_models/weights.best.InceptionV3.hdf5
# 6680/6680 [==============================] - 2s 360us/step - loss: 1.1973 - acc: 0.7007 - val_loss: 0.7087 - val_acc: 0.7952
# Epoch 2/20
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.4450 - acc: 0.8604
# Epoch 00002: val_loss improved from 0.70868 to 0.59187, saving model to saved_models/weights.best.InceptionV3.hdf5
# 6680/6680 [==============================] - 2s 294us/step - loss: 0.4465 - acc: 0.8599 - val_loss: 0.5919 - val_acc: 0.8251
# Epoch 3/20
# 6464/6680 [============================>.] - ETA: 0s - loss: 0.3248 - acc: 0.8971
# Epoch 00003: val_loss did not improve
# 6680/6680 [==============================] - 2s 281us/step - loss: 0.3230 - acc: 0.8976 - val_loss: 0.6316 - val_acc: 0.8443
# Epoch 4/20
# 6624/6680 [============================>.] - ETA: 0s - loss: 0.2657 - acc: 0.9136
# Epoch 00004: val_loss did not improve
# 6680/6680 [==============================] - 2s 244us/step - loss: 0.2663 - acc: 0.9135 - val_loss: 0.6711 - val_acc: 0.8335
# Epoch 5/20
# 6656/6680 [============================>.] - ETA: 0s - loss: 0.1997 - acc: 0.9318
# Epoch 00005: val_loss did not improve
# 6680/6680 [==============================] - 2s 260us/step - loss: 0.2020 - acc: 0.9314 - val_loss: 0.6945 - val_acc: 0.8311
# Epoch 6/20
# 6496/6680 [============================>.] - ETA: 0s - loss: 0.1645 - acc: 0.9429
# Epoch 00006: val_loss did not improve
# 6680/6680 [==============================] - 2s 257us/step - loss: 0.1652 - acc: 0.9431 - val_loss: 0.6850 - val_acc: 0.8383
# Epoch 7/20
# 6496/6680 [============================>.] - ETA: 0s - loss: 0.1330 - acc: 0.9587
# Epoch 00007: val_loss did not improve
# 6680/6680 [==============================] - 2s 262us/step - loss: 0.1326 - acc: 0.9590 - val_loss: 0.6994 - val_acc: 0.8515
# Epoch 8/20
# 6464/6680 [============================>.] - ETA: 0s - loss: 0.1081 - acc: 0.9641
# Epoch 00008: val_loss did not improve
# 6680/6680 [==============================] - 2s 244us/step - loss: 0.1082 - acc: 0.9644 - val_loss: 0.6778 - val_acc: 0.8491
# Epoch 9/20
# 6656/6680 [============================>.] - ETA: 0s - loss: 0.0885 - acc: 0.9709
# Epoch 00009: val_loss did not improve
# 6680/6680 [==============================] - 2s 291us/step - loss: 0.0889 - acc: 0.9705 - val_loss: 0.7258 - val_acc: 0.8431
# Epoch 10/20
# 6528/6680 [============================>.] - ETA: 0s - loss: 0.0750 - acc: 0.9759
# Epoch 00010: val_loss did not improve
# 6680/6680 [==============================] - 2s 319us/step - loss: 0.0754 - acc: 0.9756 - val_loss: 0.7583 - val_acc: 0.8431
# Epoch 11/20
# 6656/6680 [============================>.] - ETA: 0s - loss: 0.0637 - acc: 0.9797
# Epoch 00011: val_loss did not improve
# 6680/6680 [==============================] - 2s 267us/step - loss: 0.0636 - acc: 0.9798 - val_loss: 0.7169 - val_acc: 0.8479
# Epoch 12/20
# 6592/6680 [============================>.] - ETA: 0s - loss: 0.0544 - acc: 0.9819
# Epoch 00012: val_loss did not improve
# 6680/6680 [==============================] - 2s 305us/step - loss: 0.0541 - acc: 0.9820 - val_loss: 0.7700 - val_acc: 0.8455
# Epoch 13/20
# 6624/6680 [============================>.] - ETA: 0s - loss: 0.0430 - acc: 0.9876
# Epoch 00013: val_loss did not improve
# 6680/6680 [==============================] - 2s 345us/step - loss: 0.0431 - acc: 0.9876 - val_loss: 0.7800 - val_acc: 0.8455
# Epoch 14/20
# 6656/6680 [============================>.] - ETA: 0s - loss: 0.0393 - acc: 0.9878
# Epoch 00014: val_loss did not improve
# 6680/6680 [==============================] - 2s 368us/step - loss: 0.0394 - acc: 0.9879 - val_loss: 0.7764 - val_acc: 0.8443
# Epoch 15/20
# 6528/6680 [============================>.] - ETA: 0s - loss: 0.0327 - acc: 0.9900
# Epoch 00015: val_loss did not improve
# 6680/6680 [==============================] - 2s 292us/step - loss: 0.0325 - acc: 0.9901 - val_loss: 0.8082 - val_acc: 0.8563
# Epoch 16/20
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.0262 - acc: 0.9916
# Epoch 00016: val_loss did not improve
# 6680/6680 [==============================] - 2s 329us/step - loss: 0.0265 - acc: 0.9915 - val_loss: 0.8704 - val_acc: 0.8515
# Epoch 17/20
# 6496/6680 [============================>.] - ETA: 0s - loss: 0.0237 - acc: 0.9925
# Epoch 00017: val_loss did not improve
# 6680/6680 [==============================] - 2s 307us/step - loss: 0.0241 - acc: 0.9922 - val_loss: 0.8362 - val_acc: 0.8479
# Epoch 18/20
# 6496/6680 [============================>.] - ETA: 0s - loss: 0.0221 - acc: 0.9942
# Epoch 00018: val_loss did not improve
# 6680/6680 [==============================] - 2s 336us/step - loss: 0.0218 - acc: 0.9943 - val_loss: 0.8216 - val_acc: 0.8527
# Epoch 19/20
# 6592/6680 [============================>.] - ETA: 0s - loss: 0.0185 - acc: 0.9950
# Epoch 00019: val_loss did not improve
# 6680/6680 [==============================] - 2s 249us/step - loss: 0.0183 - acc: 0.9951 - val_loss: 0.8443 - val_acc: 0.8551
# Epoch 20/20
# 6592/6680 [============================>.] - ETA: 0s - loss: 0.0175 - acc: 0.9944
# Epoch 00020: val_loss did not improve
# 6680/6680 [==============================] - 2s 271us/step - loss: 0.0173 - acc: 0.9945 - val_loss: 0.8286 - val_acc: 0.8515

# %% [markdown]
# ### (IMPLEMENTATION) Load the Model with the Best Validation Loss

# %%
### TODO: Load the model weights with the best validation loss.
# ResNet50_model.load_weights('saved_models/weights.best.ResNet50.hdf5')
InceptionV3_model.load_weights('saved_models/weights.best.InceptionV3.hdf5')

# %% [markdown]
# ### (IMPLEMENTATION) Test the Model
#
# Try out your model on the test dataset of dog images. Ensure that your test accuracy is greater than 60%.

# %%
### TODO: Calculate classification accuracy on the test dataset.
# get index of predicted dog breed for each image in test set
# ResNet50_predictions = [np.argmax(ResNet50_model.predict(np.expand_dims(feature, axis=0))) for feature in test_ResNet50]

# # report test accuracy
# test_accuracy = 100*np.sum(np.array(ResNet50_predictions)==np.argmax(test_targets, axis=1))/len(ResNet50_predictions)
# print('Test accuracy: %.4f%%' % test_accuracy)
InceptionV3_predictions = [np.argmax(InceptionV3_model.predict(np.expand_dims(feature, axis=0)))
                     for feature in test_InceptionV3]

# report test accuracy
test_accuracy = 100*np.sum(np.array(InceptionV3_predictions)==
                           np.argmax(test_targets, axis=1))/len(InceptionV3_predictions)
print('\nTest accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 79.0000%

# %% [markdown]
# ### (IMPLEMENTATION) Predict Dog Breed with the Model
#
# Write a function that takes an image path as input and returns the dog breed (`Affenpinscher`, `Afghan_hound`, etc) that is predicted by your model.
#
# Similar to the analogous function in Step 5, your function should have three steps:
# 1. Extract the bottleneck features corresponding to the chosen CNN model.
# 2. Supply the bottleneck features as input to the model to return the predicted vector.  Note that the argmax of this prediction vector gives the index of the predicted dog breed.
# 3. Use the `dog_names` array defined in Step 0 of this notebook to return the corresponding breed.
#
# The functions to extract the bottleneck features can be found in `extract_bottleneck_features.py`, and they have been imported in an earlier code cell.  To obtain the bottleneck features corresponding to your chosen CNN architecture, you need to use the function
#
#     extract_{network}
#
# where `{network}`, in the above filename, should be one of `VGG19`, `Resnet50`, `InceptionV3`, or `Xception`.

# %%
from extract_bottleneck_features import *
### TODO: Write a function that takes a path to an image as input
### and returns the dog breed that is predicted by the model.
# def ResNet50_predict_breed(img_path):
#     # extract bottleneck features
#     bottleneck_feature = extract_ResNet50(path_to_tensor(img_path))
#     # obtain predicted vector
#     predicted_vector = ResNet50_model.predict(bottleneck_feature)
#     # return dog breed that is predicted by the model
#     return dog_names[np.argmax(predicted_vector)]

def InceptionV3_predict_breed(img_path):
    # extract bottleneck features
    bottleneck_feature = extract_InceptionV3(path_to_tensor(img_path))
    # obtain predicted vector
    predicted_vector = InceptionV3_model.predict(bottleneck_feature)
    # return dog breed that is predicted by the model
    return dog_names[np.argmax(predicted_vector)]

# %% [markdown]
# ---
# <a id='step6'></a>
# ## Step 6: Write your Algorithm
#
# Write an algorithm that accepts a file path to an image and first determines whether the image contains a human, dog, or neither.  Then,
# - if a __dog__ is detected in the image, return the predicted breed.
# - if a __human__ is detected in the image, return the resembling dog breed.
# - if __neither__ is detected in the image, provide output that indicates an error.
#
# You are welcome to write your own functions for detecting humans and dogs in images, but feel free to use the `face_detector` and `dog_detector` functions developed above.  You are __required__ to use your CNN from Step 5 to predict dog breed.
#
# Some sample output for our algorithm is provided below, but feel free to design your own user experience!
#
# ![Sample Human Output](images/sample_human_output.png)
#
#
# ### (IMPLEMENTATION) Write your Algorithm

# %%
### TODO: Write your algorithm.
### Feel free to use as many code cells as needed.
def dog_prediction_algo(img_path):
    face_detected = face_detector(img_path)
    dog_detected = dog_detector(img_path)
    if face_detector or dog_detector:
        #return ResNet50_predict_breed(img_path)
        return InceptionV3_predict_breed(img_path)
    else:
        print 'No Face detected'

# %% [markdown]
# ---
# <a id='step7'></a>
# ## Step 7: Test Your Algorithm
#
# In this section, you will take your new algorithm for a spin!  What kind of dog does the algorithm think that __you__ look like?  If you have a dog, does it predict your dog's breed accurately?  If you have a cat, does it mistakenly think that your cat is a dog?
#
# ### (IMPLEMENTATION) Test Your Algorithm on Sample Images!
#
# Test your algorithm at least six images on your computer.  Feel free to use any images you like.  Use at least two human and two dog images.
#
# __Question 6:__ Is the output better than you expected :) ?  Or worse :( ?  Provide at least three possible points of improvement for your algorithm.
#
# __Answer:__
#
# The output is about the same as what I expected.
#
# The dog breeds were predicted accurately,
# But smile.png was mistaken as a breeds of dog and also the same behaviour for shark(Maltese) and human faces Ellen (Australian_cattle_dog) and Kety(Chinese_crested)

# %%
## TODO: Execute your algorithm from Step 6 on
## at least 6 images on your computer.
## Feel free to use as many code cells as needed.
print("Let's talk about the image images/Brittany_02625.jpg. Its a dog of bread %s." % dog_prediction_algo('images/Brittany_02625.jpg'))
print("Let's talk about the image images/American_water_spaniel_00648.jpg. Its a dog of bread %s." % dog_prediction_algo('images/American_water_spaniel_00648.jpg'))
print("Let's talk about the image images/Curly-coated_retriever_03896.jpg. Its a dog of bread %s." % dog_prediction_algo('images/Curly-coated_retriever_03896.jpg'))
print("Let's talk about the image images/Labrador_retriever_06449.jpg. Its a dog of bread %s." % dog_prediction_algo('images/Labrador_retriever_06449.jpg'))
print("Let's talk about the image images/Labrador_retriever_06455.jpg. Its a dog of bread %s." % dog_prediction_algo('images/Labrador_retriever_06455.jpg'))
print("Let's talk about the image images/Labrador_retriever_06457.jpg. Its a dog of bread %s." % dog_prediction_algo('images/Labrador_retriever_06457.jpg'))

print("Let's talk about the image images/Welsh_springer_spaniel_08203.jpg. Its a dog of bread %s." % dog_prediction_algo('images/Welsh_springer_spaniel_08203.jpg'))

print("Let's talk about the image images/smile.png. Its a dog of bread %s." % dog_prediction_algo('images/smile.png'))

print("Let's talk about the image shark.jpeg. Its a dog of bread %s." % dog_prediction_algo('images/shark.jpeg'))

print("Let's talk about the image images/ellen.jpg. Predicted Bread : %s." % dog_prediction_algo('images/ellen.jpg'))

print("Let's talk about the image kety.jpeg. Predicted Bread : %s." % dog_prediction_algo('images/kety.jpeg'))
# Out:
# Let's talk about the image images/Brittany_02625.jpg. Its a dog of bread Brittany.
# Let's talk about the image images/American_water_spaniel_00648.jpg. Its a dog of bread American_water_spaniel.
# Let's talk about the image images/Curly-coated_retriever_03896.jpg. Its a dog of bread Curly-coated_retriever.
# Let's talk about the image images/Labrador_retriever_06449.jpg. Its a dog of bread Labrador_retriever.
# Let's talk about the image images/Labrador_retriever_06455.jpg. Its a dog of bread Labrador_retriever.
# Let's talk about the image images/Labrador_retriever_06457.jpg. Its a dog of bread Labrador_retriever.
# Let's talk about the image images/Welsh_springer_spaniel_08203.jpg. Its a dog of bread Welsh_springer_spaniel.
# Let's talk about the image images/smile.png. Its a dog of bread Labrador_retriever.
# Let's talk about the image shark.jpeg. Its a dog of bread Maltese.
# Let's talk about the image images/ellen.jpg. Predicted Bread : Australian_cattle_dog.
# Let's talk about the image kety.jpeg. Predicted Bread : Chinese_crested.
